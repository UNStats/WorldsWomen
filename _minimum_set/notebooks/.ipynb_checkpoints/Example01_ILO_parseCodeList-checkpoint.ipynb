# %% [markdown]
# # Example 01: Parse a specific ILO Code List
#
# This examples shows how to parse a code list from the ILO's SDMX API (ILOSTAT SDMX Gateway).

# %% [markdown]
# ### Load required libraries

# %%
import xmltodict
import json
import requests 
import xml.etree.ElementTree as ET

# %% [markdown]
# ### Interactive shell

# %%
# https://volderette.de/jupyter-notebook-tip-multiple-outputs/
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Get data from API endpoint and save as xml file on disk

# %%
baseURL = 'http://www.ilo.org/ilostat/sdmx/ws/rest/'

# url of API endpoint
url = baseURL + 'codelist/ILO/CL_ECO'

# creating HTTP response object from given url 
resp = requests.get(url) 

# saving the xml message into an xml file 
with open('test.xml', 'wb') as f: 
    f.write(resp.content)
# Out:
# 117586

# %% [markdown]
# ### Open xml file using `xmltodict.parse`
# This will create an object consisting of various nested ordered dictionaries. Every node of the XML tree is an ordered dictionary of key-value pairs. The root of the XML tree is an ordered dictionary itself.

# %%
xmlFile = 'test.xml'

with open(xmlFile) as fd:
    doc = xmltodict.parse(fd.read())

# %% [markdown]
# ### Drill down to level 3, which contains the actual code list

# %%
print('---Root:')
len(doc)
rootKey = list(doc.keys())[0]
rootKey

print('---Level 1:')
level1 = doc[rootKey]
len(level1)
level1Keys = list(level1.keys())
level1Keys

print('---Level 2 / mes:CodeLists')
level2 = level1['mes:CodeLists']
len(level2)
level2Keys = list(level2.keys())
level2Keys

print('---Level 3 / mes:CodeList')
level3 = level2['str:CodeList']
len(level3)
level3Keys = list(level3.keys())
level3Keys
# Out:
# ---Root:
# 1
# 'mes:Structure'
# ---Level 1:
# 5
# ['@xmlns:mes', '@xmlns:str', '@xmlns:com', 'mes:Header', 'mes:CodeLists']
# ---Level 2 / mes:CodeLists
# 1
# ['str:CodeList']
# ---Level 3 / mes:CodeList
# 8
# ['@agencyID',
#  '@id',
#  '@urn',
#  '@version',
#  '@isFinal',
#  'str:Name',
#  'str:Description',
#  'str:Code']

# %% [markdown]
# ### Collect the code list information in a dictionary

# %%
codeList = {}

codeList['agencyId'] = level3['@agencyID']
codeList['id'] = level3['@id']
codeList['urn'] = level3['@urn']
codeList['version'] = level3['@version']
codeList['isFinal'] = level3['@isFinal']

codeListName = level3['str:Name']
for x in codeListName:
    if x['@xml:lang'] == 'en':
        codeList['nameEN'] = x['#text']
    if x['@xml:lang'] == 'es':
        codeList['nameES'] = x['#text']
    if x['@xml:lang'] == 'fr':
        codeList['nameFR'] = x['#text']

codeListDescription  = level3['str:Description']
for x in codeListDescription:
    if x['@xml:lang'] == 'en':
        codeList['descriptionEN'] = x['#text']
    if x['@xml:lang'] == 'es':
        codeList['descriptionES'] = x['#text']
    if x['@xml:lang'] == 'fr':
        codeList['descriptionFR'] = x['#text']

codeList['codes'] = []
for c in level3['str:Code']:
    code = {}
    code['value'] = c['@value']
    
    codeValueDescription = c['str:Description']
    for x in codeValueDescription:
        if x['@xml:lang'] == 'en':
            code['descriptionEN'] = x['#text']
        if x['@xml:lang'] == 'es':
            code['descriptionES'] = x['#text']
        if x['@xml:lang'] == 'fr':
            code['descriptionFR'] = x['#text']
    codeList['codes'].append(code)

codeList
# Out:
# {'agencyId': 'ILO',
#  'id': 'CL_ECO',
#  'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Codelist=ILO:CL_ECO(1.0)',
#  'version': '1.0',
#  'isFinal': 'true',
#  'nameES': 'Actividad econÃ³mica',
#  'nameEN': 'Economic activity',
#  'nameFR': 'ActivitÃ© Ã©conomique',
#  'descriptionES': '<p>Este tipo de clasificaci&oacute;n hace referencia a la actividad principal del establecimiento en el que la persona trabaj&oacute; durante el per&iacute;odo de referencia, o a la del &uacute;ltimo establecimiento en que trabaj&oacute; en el caso de los desocupados. La rama de actividad econ&oacute;mica de una persona no depende de las tareas o funciones espec&iacute;ficas de su empleo, sino de las caracter&iacute;sticas de la unidad econ&oacute;mica en que trabaja. Los temas desagregados por actividad econ&oacute;mica se presentan utilizando la versi&oacute;n m&aacute;s reciente disponible de la Clasificaci&oacute;n Industrial Internacional Uniforme de todas las actividades econ&oacute;micas (CIIU). Puede que los datos hayan sido reclasificados a partir de la clasificaci&oacute;n industrial nacional, que quiz&aacute; no sea estrictamente comparable con la CIIU.</p>',
#  'descriptionEN': '<p>This type of classification refers to the main activity of the establishment in which a person worked during the reference period, or last worked if unemployed. The branch of economic activity of a person does not depend on the specific duties or functions of the person&rsquo;s job, but on the characteristics of the economic unit in which this person works. Topics disaggregated by economic activity are provided according to the latest version of the International Standard Industrial Classification of All Economic Activities (ISIC) available for that year. Data may have been regrouped from the national industrial classification, which may not be strictly compatible with ISIC.</p>',
#  'descriptionFR': '<p>Ce type de classification fait r&eacute;f&eacute;rence &agrave; l&#39;activit&eacute; principale de l&#39;&eacute;tablissement dans lequel la personne a travaill&eacute; pendant la p&eacute;riode de r&eacute;f&eacute;rence, ou a travaill&eacute; en dernier si la personne est au ch&ocirc;mage. La branche d&#39;activit&eacute; &eacute;conomique d&#39;une personne ne d&eacute;pend pas des t&acirc;ches ou des fonctions sp&eacute;cifiques du travail de la personne, mais des caract&eacute;ristiques de l&#39;entit&eacute; &eacute;conomique dans laquelle cette personne travaille. Les donn&eacute;es ventil&eacute;es par activit&eacute; &eacute;conomique sont pr&eacute;sent&eacute;es conform&eacute;ment &agrave; la version plus r&eacute;cente de la Classification internationale type des industries (CITI) disponible. Les donn&eacute;es peuvent avoir &eacute;t&eacute; reclass&eacute;es &agrave; partir de classifications industrielles nationales, qui peuvent ne pas &ecirc;tre strictement comparables &agrave; la CITI.</p>',
#  'codes': [{'value': 'ECO_ISIC4_R',
#    'descriptionEN': 'R. Arts, entertainment and recreation',
#    'descriptionES': 'R. Actividades artÃ\xadsticas, de entretenimiento y recreativas',
#    'descriptionFR': 'R. Arts, spectacles et loisirs'},
#   {'value': 'ECO_ISIC4_E_36',
#    'descriptionEN': '36 - Water collection, treatment and supply',
#    'descriptionES': '36 - CaptaciÃ³n, tratamiento y distribuciÃ³n de agua',
#    'descriptionFR': "36 - Collecte et traitement des eaux, distribution d'eau"},
#   {'value': 'ECO_ISIC4_S',
#    'descriptionEN': 'S. Other service activities',
#    'descriptionES': 'S. Otras actividades de servicios',
#    'descriptionFR': 'S. Autres activitÃ©s de services'},
#   {'value': 'ECO_ISIC4_P',
#    'descriptionEN': 'P. Education',
#    'descriptionES': 'P. EnseÃ±anza',
#    'descriptionFR': 'P. Ã‰ducation'},
#   {'value': 'ECO_ISIC4_Q',
#    'descriptionEN': 'Q. Human health and social work activities',
#    'descriptionES': 'Q. Actividades de atenciÃ³n de la salud humana y de asistencia social',
#    'descriptionFR': "Q. SantÃ© et et activitÃ©s d'action sociale"},
#   {'value': 'ECO_ISIC4_T',
#    'descriptionEN': 'T. Activities of households as employers; undifferentiated goods- and services-producing activities of households for own use',
#    'descriptionES': 'T. Actividades de los hogares como empleadores; actividades no diferenciadas de los hogares como productores de bienes y servicios para uso propio',
#    'descriptionFR': 'T. ActivitÃ©s des mÃ©nages privÃ©s employant du personnel domestique; activitÃ©s non diffÃ©renciÃ©es de production de biens et de services des mÃ©nages privÃ©s pour usage propre'},
#   {'value': 'ECO_ISIC4_C_21',
#    'descriptionEN': '21 - Manufacture of basic pharmaceutical products and pharmaceutical preparations.',
#    'descriptionES': '21 - FabricaciÃ³n de productos farmacÃ©uticos, sustancias quÃ\xadmicas medicinales y productos botÃ¡nicos de uso farmacÃ©utico',
#    'descriptionFR': "21 - Fabrication de prÃ©parations pharmaceutiques, de produits chimiques Ã\xa0 usage mÃ©dicinal et de produits d'herboristerie"},
#   {'value': 'ECO_ISIC4_U',
#    'descriptionEN': 'U. Activities of extraterritorial organizations and bodies',
#    'descriptionES': 'U. Actividades de organizaciones y Ã³rganos extraterritoriales',
#    'descriptionFR': 'U. ActivitÃ©s des organisations et organismes extra-territoriaux'},
#   {'value': 'ECO_ISIC4_J',
#    'descriptionEN': 'J. Information and communication',
#    'descriptionES': 'J. InformaciÃ³n y comunicaciones',
#    'descriptionFR': 'J. Information et communication'},
#   {'value': 'ECO_ISIC4_K',
#    'descriptionEN': 'K. Financial and insurance activities',
#    'descriptionES': 'K. Actividades financieras y de seguros',
#    'descriptionFR': "K. ActivitÃ©s financiÃ¨res et d'assurances"},
#   {'value': 'ECO_ISIC4_H',
#    'descriptionEN': 'H. Transportation and storage',
#    'descriptionES': 'H. Transporte y almacenamiento',
#    'descriptionFR': 'H. Transport et entreposage'},
#   {'value': 'ECO_ISIC4_I',
#    'descriptionEN': 'I. Accommodation and food service activities',
#    'descriptionES': 'I. Actividades de alojamiento y de servicio de comidas',
#    'descriptionFR': "I. ActivitÃ©s d'hÃ©bergement et de restauration"},
#   {'value': 'ECO_ISIC4_N',
#    'descriptionEN': 'N. Administrative and support service activities',
#    'descriptionES': 'N. Actividades de servicios administrativos y de apoyo',
#    'descriptionFR': "N. ActivitÃ©s de services administratifs et d'appui"},
#   {'value': 'ECO_ISIC4_O',
#    'descriptionEN': 'O. Public administration and defence; compulsory social security',
#    'descriptionES': 'O. AdministraciÃ³n pÃºblica y defensa; planes de seguridad social de afiliaciÃ³n obligatoria',
#    'descriptionFR': 'O. Administration publique et dÃ©fense; sÃ©curitÃ© sociale obligatoire'},
#   {'value': 'ECO_ISIC4_J_61',
#    'descriptionEN': '61 - Telecommunications',
#    'descriptionES': '61 - Telecomunicaciones',
#    'descriptionFR': '61 - TÃ©lÃ©communications'},
#   {'value': 'ECO_ISIC4_L',
#    'descriptionEN': 'L. Real estate activities',
#    'descriptionES': 'L. Actividades inmobiliarias',
#    'descriptionFR': 'L. ActivitÃ©s immobiliÃ¨res'},
#   {'value': 'ECO_ISIC4_M',
#    'descriptionEN': 'M. Professional, scientific and technical activities',
#    'descriptionES': 'M. Actividades profesionales, cientÃ\xadficas y tÃ©cnicas',
#    'descriptionFR': 'M. ActivitÃ©s professionnelles, scientifiques et techniques'},
#   {'value': 'ECO_ISIC4_C',
#    'descriptionEN': 'C. Manufacturing',
#    'descriptionES': 'C. Industrias manufactureras',
#    'descriptionFR': 'C. ActivitÃ©s de fabrication'},
#   {'value': 'ECO_ISIC4_B',
#    'descriptionEN': 'B. Mining and quarrying',
#    'descriptionES': 'B. ExplotaciÃ³n de minas y canteras',
#    'descriptionFR': 'B. ActivitÃ©s extractives'},
#   {'value': 'ECO_ISIC4_Q_86',
#    'descriptionEN': '86 - Human health activities',
#    'descriptionES': '86 - Actividades de atenciÃ³n de la salud humana',
#    'descriptionFR': '86 - ActivitÃ©s relatives Ã\xa0 la santÃ©'},
#   {'value': 'ECO_ISIC4_G_46',
#    'descriptionEN': '46 - Wholesale trade, except of motor vehicles and motorcycles.',
#    'descriptionES': '46 - Comercio al por mayor, excepto el de vehÃ\xadculos automotores y motocicletas',
#    'descriptionFR': "46 - Commerce de gros Ã\xa0 l'exception des vÃ©hicules automobiles et des motocycles"},
#   {'value': 'ECO_ISIC4_A',
#    'descriptionEN': 'A. Agriculture; forestry and fishing',
#    'descriptionES': 'A. Agricultura; ganaderÃ\xada; silvicultura y pesca',
#    'descriptionFR': 'A. Agriculture; sylviculture et pÃªche'},
#   {'value': 'ECO_ISIC4_G_47',
#    'descriptionEN': '47 - Retail trade, except of motor vehicles and motorcycles',
#    'descriptionES': '47 - Comercio al por menor, excepto el de vehÃ\xadculos automotores y motocicletas',
#    'descriptionFR': "47 - Commerce de dÃ©tail Ã\xa0 l'exception des vÃ©hicules automobiles et des motocycles"},
#   {'value': 'ECO_ISIC4_G',
#    'descriptionEN': 'G. Wholesale and retail trade; repair of motor vehicles and motorcycles',
#    'descriptionES': 'G. Comercio al por mayor y al por menor; reparaciÃ³n de vehÃ\xadculos automotores y motocicletas',
#    'descriptionFR': 'G. Commerce de gros et de dÃ©tail, rÃ©parations de vÃ©hicules automobiles et de motocycles'},
#   {'value': 'ECO_ISIC4_H_49',
#    'descriptionEN': '49 - Land transport and transport via pipelines',
#    'descriptionES': '49 - Transporte por vÃ\xada terrestre y transporte por tuberÃ\xadas',
#    'descriptionFR': '49 - Transports terrestres, transport par conduites'},
#   {'value': 'ECO_ISIC4_F',
#    'descriptionEN': 'F. Construction',
#    'descriptionES': 'F. ConstrucciÃ³n',
#    'descriptionFR': 'F. Construction'},
#   {'value': 'ECO_ISIC4_E',
#    'descriptionEN': 'E. Water supply; sewerage, waste management and remediation activities',
#    'descriptionES': 'E. Suministro de agua; evacuaciÃ³n de aguas residuales, gestiÃ³n de desechos y descontaminaciÃ³n',
#    'descriptionFR': "E. Distribution d'eau; rÃ©seau d'assainissement; gestion des dÃ©chets et activitÃ©s de remise en Ã©tat"},
#   {'value': 'ECO_ISIC4_D',
#    'descriptionEN': 'D. Electricity; gas, steam and air conditioning supply',
#    'descriptionES': 'D. Suministro de electricidad, gas; vapor y aire acondicionado',
#    'descriptionFR': "D. Production et distribution d'Ã©lectricitÃ©; de gaz, de vapeur et climatisation"},
#   {'value': 'ECO_ISIC4_C_14',
#    'descriptionEN': '14 - Manufacture of wearing apparel',
#    'descriptionES': '14 - FabricaciÃ³n de prendas de vestir',
#    'descriptionFR': "14 - Fabrication d'articles d'habillement"},
#   {'value': 'ECO_ISIC4_C_13',
#    'descriptionEN': '13 - Manufacture of textiles',
#    'descriptionES': '13 - FabricaciÃ³n de productos textiles',
#    'descriptionFR': '13 - Fabrication de textiles'},
#   {'value': 'ECO_ISIC4_I_55',
#    'descriptionEN': '55 - Accommodation',
#    'descriptionES': '55 - Actividades de alojamiento',
#    'descriptionFR': '55 - HÃ©bergement'},
#   {'value': 'ECO_ISIC4_I_56',
#    'descriptionEN': '56 - Food and beverage service activities',
#    'descriptionES': '56 - Actividades de servicio de comidas y bebidas',
#    'descriptionFR': '56 - ActivitÃ©s de services de restauration et de consommation de boissons'},
#   {'value': 'ECO_ISIC4_C_10',
#    'descriptionEN': '10 - Manufacture of food products',
#    'descriptionES': '10 - ElaboraciÃ³n de productos alimenticios',
#    'descriptionFR': '10 - Fabrication de produits alimentaires'},
#   {'value': 'ECO_ISIC4_TOTAL',
#    'descriptionEN': 'Total',
#    'descriptionES': 'Total',
#    'descriptionFR': 'Total'},
#   {'value': 'ECO_ISIC4_C_11',
#    'descriptionEN': '11 - Manufacture of beverages',
#    'descriptionES': '11 - ElaboraciÃ³n de bebidas',
#    'descriptionFR': '11 - Fabrication de boissons'},
#   {'value': 'ECO_ISIC4_K_64',
#    'descriptionEN': '64 - Financial service activities, except insurance and pension funding.',
#    'descriptionES': '64 - Actividades de servicios financieros, excepto las de seguros y fondos de pensiones',
#    'descriptionFR': "64 - ActivitÃ©s de services financiers, Ã\xa0 l'exception des assurances et des caisses de retraite"},
#   {'value': 'ECO_ISIC4_K_65',
#    'descriptionEN': '65 - Insurance, reinsurance and pension funding, except compulsory social security.',
#    'descriptionES': '65 - Seguros, reaseguros y fondos de pensiones, excepto planes de seguridad social de afiliaciÃ³n obligatoria',
#    'descriptionFR': "65 - ActivitÃ©s d'assurances, rÃ©assurance et de caisses de retraite, Ã\xa0 l'exception de la sÃ©curitÃ© sociale obligatoire"},
#   {'value': 'ECO_ISIC4_C_31',
#    'descriptionEN': '31 - Manufacture of furniture',
#    'descriptionES': '31 - FabricaciÃ³n de muebles',
#    'descriptionFR': '31 - Fabrication de meubles'},
#   {'value': 'ECO_ISIC4_A_01',
#    'descriptionEN': '01 - Crop and animal production, hunting and related service activities.',
#    'descriptionES': '01 - Agricultura, ganaderÃ\xada, caza y actividades de servicios conexas',
#    'descriptionFR': '01 - Culture et production animale, chasse et activitÃ©s de services connexes'},
#   {'value': 'ECO_ISIC4_A_03',
#    'descriptionEN': '03 - Fishing and aquaculture',
#    'descriptionES': '03 - Pesca y acuicultura',
#    'descriptionFR': '03 - PÃªche et aquaculture'},
#   {'value': 'ECO_ISIC4_F_41',
#    'descriptionEN': '41 - Construction of buildings',
#    'descriptionES': '41 - ConstrucciÃ³n de edificios',
#    'descriptionFR': '41 - Construction de bÃ¢timents'},
#   {'value': 'ECO_ISIC4_N_78',
#    'descriptionEN': '78 - Employment activities',
#    'descriptionES': '78 - Actividades de empleo',
#    'descriptionFR': "78 - ActivitÃ©s relatives Ã\xa0 l'emploi"},
#   {'value': 'ECO_ISIC4_X',
#    'descriptionEN': 'X. Not elsewhere classified',
#    'descriptionES': 'X. No clasificados en otra parte',
#    'descriptionFR': 'X. Non classÃ©s ailleurs'},
#   {'value': 'ECO_ISIC3_H',
#    'descriptionEN': 'H. Hotels and restaurants',
#    'descriptionES': 'H. Hoteles y restaurantes',
#    'descriptionFR': 'H. HÃ´tels et restaurants'},
#   {'value': 'ECO_ISIC3_G',
#    'descriptionEN': 'G. Wholesale and retail trade; repair of motor vehicles, motorcycles and personal and household goods',
#    'descriptionES': 'G. Comercio al por mayor y al por menor; reparaciÃ³n de vehÃ\xadculos automotores, motocicletas, efectos personales y enseres domÃ©sticos',
#    'descriptionFR': 'G. Commerce de gros et de dÃ©tail; rÃ©paration de vÃ©hicules automobiles, de motocycles et de biens personnels et domestiques'},
#   {'value': 'ECO_ISIC3_TOTAL',
#    'descriptionEN': 'Total',
#    'descriptionES': 'Total',
#    'descriptionFR': 'Total'},
#   {'value': 'ECO_ISIC3_F',
#    'descriptionEN': 'F. Construction',
#    'descriptionES': 'F. ConstrucciÃ³n',
#    'descriptionFR': 'F. Construction'},
#   {'value': 'ECO_ISIC3_E',
#    'descriptionEN': 'E. Electricity, gas and water supply',
#    'descriptionES': 'E. Suministro de electricidad, gas y agua',
#    'descriptionFR': "E. Production et distribution d'Ã©lectricitÃ©, de gaz et d'eau"},
#   {'value': 'ECO_ISIC3_D',
#    'descriptionEN': 'D. Manufacturing',
#    'descriptionES': 'D. Industrias manufactureras',
#    'descriptionFR': 'D. ActivitÃ©s de fabrication'},
#   {'value': 'ECO_ISIC3_C',
#    'descriptionEN': 'C. Mining and quarrying',
#    'descriptionES': 'C. ExplotaciÃ³n de minas y canteras',
#    'descriptionFR': 'C. ActivitÃ©s extractives'},
#   {'value': 'ECO_ISIC3_B',
#    'descriptionEN': 'B. Fishing',
#    'descriptionES': 'B. Pesca',
#    'descriptionFR': 'B. PÃªche'},
#   {'value': 'ECO_ISIC3_A',
#    'descriptionEN': 'A. Agriculture, hunting and forestry',
#    'descriptionES': 'A. Agricultura, ganaderÃ\xada, caza y silvicultura',
#    'descriptionFR': 'A. Agriculture, chasse et sylviculture'},
#   {'value': 'ECO_ISIC3_O',
#    'descriptionEN': 'O. Other community, social and personal service activities',
#    'descriptionES': 'O. Otras actividades de servicios comunitarios, sociales y personales',
#    'descriptionFR': 'O. Autres activitÃ©s de services collectifs, sociaux et personnels'},
#   {'value': 'ECO_ISIC3_P',
#    'descriptionEN': 'P. Activities of private households as employers and undifferentiated production activities of private households',
#    'descriptionES': 'P. Hogares privados con servicio domÃ©stico',
#    'descriptionFR': 'P. MÃ©nages privÃ©s employant du personnel domestique'},
#   {'value': 'ECO_ISIC3_M',
#    'descriptionEN': 'M. Education',
#    'descriptionES': 'M. EnseÃ±anza',
#    'descriptionFR': 'M. Education'},
#   {'value': 'ECO_ISIC3_N',
#    'descriptionEN': 'N. Health and social work',
#    'descriptionES': 'N. Servicios sociales y de salud',
#    'descriptionFR': 'N. SantÃ© et action sociale'},
#   {'value': 'ECO_ISIC3_K',
#    'descriptionEN': 'K. Real estate, renting and business activities',
#    'descriptionES': 'K. Actividades inmobiliarias, empresariales y de alquiler',
#    'descriptionFR': 'K. Immobilier, locations et activitÃ©s de services aux entreprises'},
#   {'value': 'ECO_ISIC3_L',
#    'descriptionEN': 'L. Public administration and defence; compulsory social security',
#    'descriptionES': 'L. AdministraciÃ³n pÃºblica y defensa; planes de seguridad social de afiliaciÃ³n obligatoria',
#    'descriptionFR': 'L. Administration publique et dÃ©fense; sÃ©curitÃ© sociale obligatoire'},
#   {'value': 'ECO_ISIC3_I',
#    'descriptionEN': 'I. Transport, storage and communications',
#    'descriptionES': 'I. Transporte, almacenamiento y comunicaciones',
#    'descriptionFR': 'I. Transports, entreposage et communications'},
#   {'value': 'ECO_ISIC3_J',
#    'descriptionEN': 'J. Financial intermediation',
#    'descriptionES': 'J. IntermediaciÃ³n financiera',
#    'descriptionFR': 'J. IntermÃ©diation financiÃ¨re'},
#   {'value': 'ECO_ISIC3_X',
#    'descriptionEN': 'X. Not elsewhere classified',
#    'descriptionES': 'X. No clasificados en otra parte',
#    'descriptionFR': 'X. Non classÃ©s ailleurs'},
#   {'value': 'ECO_ISIC3_Q',
#    'descriptionEN': 'Q. Extraterritorial organizations and bodies',
#    'descriptionES': 'Q. Organizaciones y Ã³rganos extraterritoriales',
#    'descriptionFR': 'Q. Organisations et organismes extraterritoriaux'},
#   {'value': 'ECO_ISIC2_6',
#    'descriptionEN': '6. Wholesale and Retail Trade and Restaurants and Hotels',
#    'descriptionES': '6. Comercio al por mayor y al por menor y restaurantes y hoteles',
#    'descriptionFR': '6. Commerce de gros et de dÃ©tail; restaurants et hÃ´tels'},
#   {'value': 'ECO_ISIC2_7',
#    'descriptionEN': '7. Transport, Storage and Communication',
#    'descriptionES': '7. Transportes, almacenamiento y comunicaciones',
#    'descriptionFR': '7. Transports, entrepÃ´ts et communications'},
#   {'value': 'ECO_ISIC2_8',
#    'descriptionEN': '8. Financing, Insurance, Real Estate and Business Services',
#    'descriptionES': '8. Establecimientos financieros, seguros, bienes inmuebles y servicios prestados a las empresas',
#    'descriptionFR': '8. Banques, assurances, affaires immobiliÃ¨res et services fournis aux entreprises'},
#   {'value': 'ECO_ISIC2_9',
#    'descriptionEN': '9. Community, Social and Personal Services',
#    'descriptionES': '9. Servicios comunales, sociales y personales',
#    'descriptionFR': '9. Services fournis Ã\xa0 la collectivitÃ©, services sociaux et services personnels'},
#   {'value': 'ECO_ISIC2_2',
#    'descriptionEN': '2. Mining and Quarrying',
#    'descriptionES': '2. ExplotaciÃ³n de minas y canteras',
#    'descriptionFR': '2. Industries extractives'},
#   {'value': 'ECO_ISIC2_3',
#    'descriptionEN': '3. Manufacturing',
#    'descriptionES': '3. Industrias manufactureras',
#    'descriptionFR': '3. Industries manufacturiÃ¨res'},
#   {'value': 'ECO_ISIC2_4',
#    'descriptionEN': '4. Electricity, Gas and Water',
#    'descriptionES': '4. Electricidad, gas y agua',
#    'descriptionFR': '4. ElectricitÃ©, gaz et eau'},
#   {'value': 'ECO_ISIC2_TOTAL',
#    'descriptionEN': 'Total',
#    'descriptionES': 'Total',
#    'descriptionFR': 'Total'},
#   {'value': 'ECO_ISIC2_5',
#    'descriptionEN': '5. Construction',
#    'descriptionES': '5. ConstrucciÃ³n',
#    'descriptionFR': '5. BÃ¢timent et travaux publics'},
#   {'value': 'ECO_ISIC2_0',
#    'descriptionEN': '0. Activities not Adequately Defined',
#    'descriptionES': '0. Actividades no bien especificadas',
#    'descriptionFR': '0. ActivitÃ©s mal dÃ©signÃ©es'},
#   {'value': 'ECO_ISIC2_1',
#    'descriptionEN': '1. Agriculture, Hunting, Forestry and Fishing',
#    'descriptionES': '1. Agricultura, caza, silvicultura y pesca',
#    'descriptionFR': '1. Agriculture, chasse, sylviculture et pÃªche'},
#   {'value': 'ECO_DETAILS_F',
#    'descriptionEN': 'Construction ~ISIC rev.4 F',
#    'descriptionES': 'ConstrucciÃ³n ~CIIU rev.4 F',
#    'descriptionFR': 'Construction ~CITI rev.4 F'},
#   {'value': 'ECO_DETAILS_G',
#    'descriptionEN': 'Wholesale and retail trade; repair of motor vehicles and motorcycles ~ISIC rev.4 G',
#    'descriptionES': 'Comercio al por mayor y al por menor; reparaciÃ³n de vehÃ\xadculos automotores y motocicletas ~CIIU rev.4 G',
#    'descriptionFR': 'Commerce de gros et de dÃ©tail; rÃ©parations de vÃ©hicules automobiles et de motocycles ~CITI rev.4 G'},
#   {'value': 'ECO_DETAILS_I',
#    'descriptionEN': 'Accommodation and food service activities ~ISIC rev.4 I',
#    'descriptionES': 'Actividades de alojamiento y de servicio de comidas ~CIIU rev.4 I',
#    'descriptionFR': "ActivitÃ©s d'hÃ©bergement et de restauration ~CITI rev.4 I"},
#   {'value': 'ECO_DETAILS_HJ',
#    'descriptionEN': 'Transport; storage and communication ~ISIC rev.4 H; J',
#    'descriptionES': 'Transporte; almacenamiento y comunicaciÃ³n ~CIIU rev.4 H; J',
#    'descriptionFR': 'Transport; stockage et communication ~CITI rev.4 H; J'},
#   {'value': 'ECO_DETAILS_K',
#    'descriptionEN': 'Financial and insurance activities ~ISIC rev.4 K',
#    'descriptionES': 'Actividades financieras y de seguros ~CIIU rev.4 K',
#    'descriptionFR': "ActivitÃ©s financiÃ¨res et d'assurances ~CITI rev.4 K"},
#   {'value': 'ECO_DETAILS_O',
#    'descriptionEN': 'Public administration and defence; compulsory social security ~ISIC rev.4 O',
#    'descriptionES': 'AdministraciÃ³n pÃºblica y defensa; planes de seguridad social de afiliaciÃ³n obligatoria ~CIIU rev.4 O',
#    'descriptionFR': 'Administration publique et dÃ©fense; sÃ©curitÃ© sociale obligatoire ~CITI rev.4 O'},
#   {'value': 'ECO_DETAILS_P',
#    'descriptionEN': 'Education ~ISIC rev.4 P',
#    'descriptionES': 'EnseÃ±anza ~CIIU rev.4 P',
#    'descriptionFR': 'Ã‰ducation ~CITI rev.4 P'},
#   {'value': 'ECO_DETAILS_Q',
#    'descriptionEN': 'Human health and social work activities ~ISIC rev.4 Q',
#    'descriptionES': 'Actividades de atenciÃ³n de la salud humana y de asistencia social ~CIIU rev.4 Q',
#    'descriptionFR': "SantÃ© et et activitÃ©s d'action sociale ~CITI rev.4 Q"},
#   {'value': 'ECO_DETAILS_DE',
#    'descriptionEN': 'Utilities ~ISIC rev.4 D; E',
#    'descriptionES': 'Utilidades ~CIIU rev.4 D; E',
#    'descriptionFR': 'Utilitaires ~CITI rev.4 D; E'},
#   {'value': 'ECO_DETAILS_LMN',
#    'descriptionEN': 'Real estate; business and administrative activities ~ISIC rev.4 L; M; N',
#    'descriptionES': 'Actividades inmobiliarias; comerciales y administrativas ~CIIU rev.4 L; M; N',
#    'descriptionFR': 'ActivitÃ©s immobiliÃ¨res; commerciales et administratives ~CITI rev.4 L; M; N'},
#   {'value': 'ECO_DETAILS_RSTU',
#    'descriptionEN': 'Other services ~ISIC rev.4 R; S; T; U',
#    'descriptionES': 'Otros servicios ~CIIU rev.4 R; S; T; U',
#    'descriptionFR': 'Autres services ~CITI rev.4 R; S; T; U'},
#   {'value': 'ECO_DETAILS_TOTAL',
#    'descriptionEN': 'Total',
#    'descriptionES': 'Total',
#    'descriptionFR': 'Total'},
#   {'value': 'ECO_DETAILS_C',
#    'descriptionEN': 'Manufacturing ~ISIC rev.4 C',
#    'descriptionES': 'Industrias manufactureras ~CIIU rev.4 C',
#    'descriptionFR': 'ActivitÃ©s de fabrication ~CITI rev.4 C'},
#   {'value': 'ECO_DETAILS_B',
#    'descriptionEN': 'Mining and quarrying ~ISIC rev.4 B',
#    'descriptionES': 'ExplotaciÃ³n de minas y canteras ~CIIU rev.4 B',
#    'descriptionFR': 'ActivitÃ©s extractives ~CITI rev.4 B'},
#   {'value': 'ECO_DETAILS_A',
#    'descriptionEN': 'Agriculture; forestry and fishing ~ISIC rev.4 A',
#    'descriptionES': 'Agricultura; ganaderÃ\xada; silvicultura y pesca ~CIIU rev.4 A',
#    'descriptionFR': 'Agriculture; sylviculture et pÃªche ~CITI rev.4 A'},
#   {'value': 'ECO_AGGREGATE_MIN',
#    'descriptionEN': 'Mining and quarrying',
#    'descriptionES': 'ExplotaciÃ³n de minas y canteras',
#    'descriptionFR': 'ActivitÃ©s extractives'},
#   {'value': 'ECO_AGGREGATE_MAN',
#    'descriptionEN': 'Manufacturing',
#    'descriptionES': 'Manufacturas',
#    'descriptionFR': 'Manufacture'},
#   {'value': 'ECO_AGGREGATE_X',
#    'descriptionEN': 'Not classified',
#    'descriptionES': 'Sin clasificar',
#    'descriptionFR': 'Non classÃ©'},
#   {'value': 'ECO_AGGREGATE_MANEL',
#    'descriptionEN': 'Manufacturing; Electricity, gas and water supply',
#    'descriptionES': 'Manufacturas; Suministro de electricidad, gas y agua',
#    'descriptionFR': "Manufacture; Production et distribution d'Ã©lectricitÃ©, de gaz et d'eau"},
#   {'value': 'ECO_AGGREGATE_MEL',
#    'descriptionEN': 'Mining and quarrying; Electricity, gas and water supply',
#    'descriptionES': 'ExplotaciÃ³n de minas y canteras; Suministro de electricidad, gas y agua',
#    'descriptionFR': "ActivitÃ©s extractives; Production et distribution d'Ã©lectricitÃ©, de gaz et d'eau"},
#   {'value': 'ECO_AGGREGATE_MKT',
#    'descriptionEN': 'Trade, Transportation, Accommodation and Food, and Business and Administrative Services',
#    'descriptionES': 'Comercio, Transporte, Hoteles y Restaurantes, y actividades empresariales',
#    'descriptionFR': 'Commerce, Transports, HÃ´tels et restaurants et activitÃ©s de services aux enterprises'},
#   {'value': 'ECO_AGGREGATE_AGR',
#    'descriptionEN': 'Agriculture',
#    'descriptionES': 'Agricultura',
#    'descriptionFR': 'Agriculture'},
#   {'value': 'ECO_AGGREGATE_CON',
#    'descriptionEN': 'Construction',
#    'descriptionES': 'ConstrucciÃ³n',
#    'descriptionFR': 'Construction'},
#   {'value': 'ECO_AGGREGATE_TOTAL',
#    'descriptionEN': 'Total',
#    'descriptionES': 'Total',
#    'descriptionFR': 'Total'},
#   {'value': 'ECO_AGGREGATE_PUB',
#    'descriptionEN': 'Public Administration, Community, Social and other Services and Activities',
#    'descriptionES': 'AdministraciÃ³n pÃºblica y servicios y actividades comunales y sociales',
#    'descriptionFR': 'Administration publique et activitÃ©s de services collectifs, sociaux et personnels'},
#   {'value': 'ECO_SECTOR_AGR',
#    'descriptionEN': 'Agriculture',
#    'descriptionES': 'Agricultura',
#    'descriptionFR': 'Agriculture'},
#   {'value': 'ECO_SECTOR_TOTAL',
#    'descriptionEN': 'Total',
#    'descriptionES': 'Total',
#    'descriptionFR': 'Total'},
#   {'value': 'ECO_SECTOR_SER',
#    'descriptionEN': 'Services',
#    'descriptionES': 'Servicios',
#    'descriptionFR': 'Services'},
#   {'value': 'ECO_SECTOR_X',
#    'descriptionEN': 'Not classified',
#    'descriptionES': 'No clasificados',
#    'descriptionFR': 'Non classÃ©'},
#   {'value': 'ECO_SECTOR_IND',
#    'descriptionEN': 'Industry',
#    'descriptionES': 'Industria',
#    'descriptionFR': 'Industrie'},
#   {'value': 'ECO_TOTNAG_TOTAL',
#    'descriptionEN': 'Total',
#    'descriptionES': 'Total',
#    'descriptionFR': 'Total'},
#   {'value': 'ECO_TOTNAG_NAG',
#    'descriptionEN': 'Non-agriculture',
#    'descriptionES': 'No agrÃ\xadcola',
#    'descriptionFR': 'Non agricole'},
#   {'value': 'ECO_AGNAG_AGR',
#    'descriptionEN': 'Agriculture',
#    'descriptionES': 'Agricultura',
#    'descriptionFR': 'Agriculture'},
#   {'value': 'ECO_AGNAG_TOTAL',
#    'descriptionEN': 'Total',
#    'descriptionES': 'Total',
#    'descriptionFR': 'Total'},
#   {'value': 'ECO_AGNAG_NAG',
#    'descriptionEN': 'Non-agriculture',
#    'descriptionES': 'No agrÃ\xadcola',
#    'descriptionFR': 'Non agricole'},
#   {'value': '_Z',
#    'descriptionEN': 'Not Applicable',
#    'descriptionES': 'No aplicable en el caso',
#    'descriptionFR': 'Non Applicable'}]}
