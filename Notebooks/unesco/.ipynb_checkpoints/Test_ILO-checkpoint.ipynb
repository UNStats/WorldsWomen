# %% [markdown]
# # Python code to illustrate parsing of XML files
#
# This example is based on `https://www.datacamp.com/community/tutorials/python-xml-elementtree`

# %% [markdown]
# ### Importing the required modules

# %%
import csv 
import requests 
import xml.etree.ElementTree as ET

# %% [markdown]
# the `ElementTree` library has functions to read and manipulate XML files (and other similarly structured files).

# %% [markdown]
# ## Get the XML data

# %% [markdown]
# ### Request XML data from an API endpoint and save it to a file on disk

# %%
# url of API endpoint
url = 'https://www.ilo.org/ilostat/sdmx/ws/rest/codelist/ILO/CL_ECO'

# creating HTTP response object from given url 
resp = requests.get(url) 

# saving the xml message into an xml file 
with open('test.xml', 'wb') as f: 
    f.write(resp.content)

# %% [markdown]
# ### Read the XML file with `ElementTree`

# %%
xmlfile = 'test.xml'

# create element tree object 
tree = ET.parse(xmlfile)

# %% [markdown]
# ## Look at the XML and print out values in order to understand how the tree is structured.

# %% [markdown]
# Every part of a tree (root included) has:
# - a tag that describes the element
# - (optional) attributes

# %% [markdown]
# ### Get the root element of the XML tree

# %%
root = tree.getroot()
root
# Out:
# <Element '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}Structure' at 0x0000021B6F40E7C8>

# %%
root.tag
# Out:
# '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}Structure'

# %%
root.attrib
# Out:
# {}

# %% [markdown]
# ### Iterate over children in the root using a `for` loop

# %%
for child in root:
    print(child.tag, child.attrib)
# Out:
# {http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}Header {}
# {http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}CodeLists {}

# %% [markdown]
# ### List all the elements in the entire tree using `root.iter()`

# %% [markdown]
# This gives a general notion for how many elements are in the XML file, but it does not show the attributes or levels in the tree.

# %%
elements = [elem.tag for elem in root.iter()]
elements
# Out:
# ['{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}Structure',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}Header',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}ID',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}Test',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}Prepared',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}Sender',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}Receiver',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message}CodeLists',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}CodeList',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Name',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Name',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Name',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
# ...
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}Annotation',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationTitle',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common}AnnotationText',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Description',
#  '{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Annotations',
#  ...]

# %% [markdown]
# ### See the whole document passing the root into the `.tostring()` method

# %% [markdown]
# Since the `ElementTree` library can interpret more than just XML, you must specify both the encoding and decoding of the document to be displayed displaying as the string (`'utf8'` is the typical document encoding for XML files).

# %%
print(ET.tostring(root, encoding='utf8').decode('utf8'))
# Out:
# <?xml version='1.0' encoding='utf8'?>
# <ns0:Structure xmlns:ns0="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message" xmlns:ns1="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure" xmlns:ns2="http://www.SDMX.org/resources/SDMXML/schemas/v2_0/common">
#   <ns0:Header>
#     <ns0:ID>IDREF3877</ns0:ID>
#     <ns0:Test>false</ns0:Test>
#     <ns0:Prepared>2019-08-09T13:04:25.694Z</ns0:Prepared>
#     <ns0:Sender id="Unknown" />
#     <ns0:Receiver id="Unknown" />
#   </ns0:Header>
#   <ns0:CodeLists>
#     <ns1:CodeList agencyID="ILO" id="CL_ECO" isFinal="true" urn="urn:sdmx:org.sdmx.infomodel.codelist.Codelist=ILO:CL_ECO(1.0)" version="1.0">
#       <ns1:Name xml:lang="es">Actividad económica</ns1:Name>
#       <ns1:Name xml:lang="en">Economic activity</ns1:Name>
#       <ns1:Name xml:lang="fr">Activité économique</ns1:Name>
#       <ns1:Description xml:lang="es">&lt;p&gt;Este tipo de clasificaci&amp;oacute;n hace referencia a la actividad principal del establecimiento en el que la persona trabaj&amp;oacute; durante el per&amp;iacute;odo de referencia, o a la del &amp;uacute;ltimo establecimiento en que trabaj&amp;oacute; en el caso de los desocupados. La rama de actividad econ&amp;oacute;mica de una persona no depende de las tareas o funciones espec&amp;iacute;ficas de su empleo, sino de las caracter&amp;iacute;sticas de la unidad econ&amp;oacute;mica en que trabaja. Los temas desagregados por actividad econ&amp;oacute;mica se presentan utilizando la versi&amp;oacute;n m&amp;aacute;s reciente disponible de la Clasificaci&amp;oacute;n Industrial Internacional Uniforme de todas las actividades econ&amp;oacute;micas (CIIU). Puede que los datos hayan sido reclasificados a partir de la clasificaci&amp;oacute;n industrial nacional, que quiz&amp;aacute; no sea estrictamente comparable con la CIIU.&lt;/p&gt;</ns1:Description>
#       <ns1:Description xml:lang="en">&lt;p&gt;This type of classification refers to the main activity of the establishment in which a person worked during the reference period, or last worked if unemployed. The branch of economic activity of a person does not depend on the specific duties or functions of the person&amp;rsquo;s job, but on the characteristics of the economic unit in which this person works. Topics disaggregated by economic activity are provided according to the latest version of the International Standard Industrial Classification of All Economic Activities (ISIC) available for that year. Data may have been regrouped from the national industrial classification, which may not be strictly compatible with ISIC.&lt;/p&gt;</ns1:Description>
#       <ns1:Description xml:lang="fr">&lt;p&gt;Ce type de classification fait r&amp;eacute;f&amp;eacute;rence &amp;agrave; l&amp;#39;activit&amp;eacute; principale de l&amp;#39;&amp;eacute;tablissement dans lequel la personne a travaill&amp;eacute; pendant la p&amp;eacute;riode de r&amp;eacute;f&amp;eacute;rence, ou a travaill&amp;eacute; en dernier si la personne est au ch&amp;ocirc;mage. La branche d&amp;#39;activit&amp;eacute; &amp;eacute;conomique d&amp;#39;une personne ne d&amp;eacute;pend pas des t&amp;acirc;ches ou des fonctions sp&amp;eacute;cifiques du travail de la personne, mais des caract&amp;eacute;ristiques de l&amp;#39;entit&amp;eacute; &amp;eacute;conomique dans laquelle cette personne travaille. Les donn&amp;eacute;es ventil&amp;eacute;es par activit&amp;eacute; &amp;eacute;conomique sont pr&amp;eacute;sent&amp;eacute;es conform&amp;eacute;ment &amp;agrave; la version plus r&amp;eacute;cente de la Classification internationale type des industries (CITI) disponible. Les donn&amp;eacute;es peuvent avoir &amp;eacute;t&amp;eacute; reclass&amp;eacute;es &amp;agrave; partir de classifications industrielles nationales, qui peuvent ne pas &amp;ecirc;tre strictement comparables &amp;agrave; la CITI.&lt;/p&gt;</ns1:Description>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_R" value="ECO_ISIC4_R">
#         <ns1:Description xml:lang="en">R. Arts, entertainment and recreation</ns1:Description>
#         <ns1:Description xml:lang="es">R. Actividades artísticas, de entretenimiento y recreativas</ns1:Description>
#         <ns1:Description xml:lang="fr">R. Arts, spectacles et loisirs</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12860</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_E_36" value="ECO_ISIC4_E_36">
#         <ns1:Description xml:lang="en">36 - Water collection, treatment and supply</ns1:Description>
#         <ns1:Description xml:lang="es">36 - Captación, tratamiento y distribución de agua</ns1:Description>
#         <ns1:Description xml:lang="fr">36 - Collecte et traitement des eaux, distribution d'eau</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12620</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_S" value="ECO_ISIC4_S">
#         <ns1:Description xml:lang="en">S. Other service activities</ns1:Description>
#         <ns1:Description xml:lang="es">S. Otras actividades de servicios</ns1:Description>
#         <ns1:Description xml:lang="fr">S. Autres activités de services</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12870</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_P" value="ECO_ISIC4_P">
#         <ns1:Description xml:lang="en">P. Education</ns1:Description>
#         <ns1:Description xml:lang="es">P. Enseñanza</ns1:Description>
#         <ns1:Description xml:lang="fr">P. Éducation</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12830</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_Q" value="ECO_ISIC4_Q">
#         <ns1:Description xml:lang="en">Q. Human health and social work activities</ns1:Description>
#         <ns1:Description xml:lang="es">Q. Actividades de atención de la salud humana y de asistencia social</ns1:Description>
#         <ns1:Description xml:lang="fr">Q. Santé et et activités d'action sociale</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12840</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_T" value="ECO_ISIC4_T">
#         <ns1:Description xml:lang="en">T. Activities of households as employers; undifferentiated goods- and services-producing activities of households for own use</ns1:Description>
#         <ns1:Description xml:lang="es">T. Actividades de los hogares como empleadores; actividades no diferenciadas de los hogares como productores de bienes y servicios para uso propio</ns1:Description>
#         <ns1:Description xml:lang="fr">T. Activités des ménages privés employant du personnel domestique; activités non différenciées de production de biens et de services des ménages privés pour usage propre</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12880</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_21" value="ECO_ISIC4_C_21">
#         <ns1:Description xml:lang="en">21 - Manufacture of basic pharmaceutical products and pharmaceutical preparations.</ns1:Description>
#         <ns1:Description xml:lang="es">21 - Fabricación de productos farmacéuticos, sustancias químicas medicinales y productos botánicos de uso farmacéutico</ns1:Description>
#         <ns1:Description xml:lang="fr">21 - Fabrication de préparations pharmaceutiques, de produits chimiques à usage médicinal et de produits d'herboristerie</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12580</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_U" value="ECO_ISIC4_U">
#         <ns1:Description xml:lang="en">U. Activities of extraterritorial organizations and bodies</ns1:Description>
#         <ns1:Description xml:lang="es">U. Actividades de organizaciones y órganos extraterritoriales</ns1:Description>
#         <ns1:Description xml:lang="fr">U. Activités des organisations et organismes extra-territoriaux</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12890</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_J" value="ECO_ISIC4_J">
#         <ns1:Description xml:lang="en">J. Information and communication</ns1:Description>
#         <ns1:Description xml:lang="es">J. Información y comunicaciones</ns1:Description>
#         <ns1:Description xml:lang="fr">J. Information et communication</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12730</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_K" value="ECO_ISIC4_K">
#         <ns1:Description xml:lang="en">K. Financial and insurance activities</ns1:Description>
#         <ns1:Description xml:lang="es">K. Actividades financieras y de seguros</ns1:Description>
#         <ns1:Description xml:lang="fr">K. Activités financières et d'assurances</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12750</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_H" value="ECO_ISIC4_H">
#         <ns1:Description xml:lang="en">H. Transportation and storage</ns1:Description>
#         <ns1:Description xml:lang="es">H. Transporte y almacenamiento</ns1:Description>
#         <ns1:Description xml:lang="fr">H. Transport et entreposage</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12680</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_I" value="ECO_ISIC4_I">
#         <ns1:Description xml:lang="en">I. Accommodation and food service activities</ns1:Description>
#         <ns1:Description xml:lang="es">I. Actividades de alojamiento y de servicio de comidas</ns1:Description>
#         <ns1:Description xml:lang="fr">I. Activités d'hébergement et de restauration</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12700</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_N" value="ECO_ISIC4_N">
#         <ns1:Description xml:lang="en">N. Administrative and support service activities</ns1:Description>
#         <ns1:Description xml:lang="es">N. Actividades de servicios administrativos y de apoyo</ns1:Description>
#         <ns1:Description xml:lang="fr">N. Activités de services administratifs et d'appui</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12800</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_O" value="ECO_ISIC4_O">
#         <ns1:Description xml:lang="en">O. Public administration and defence; compulsory social security</ns1:Description>
#         <ns1:Description xml:lang="es">O. Administración pública y defensa; planes de seguridad social de afiliación obligatoria</ns1:Description>
#         <ns1:Description xml:lang="fr">O. Administration publique et défense; sécurité sociale obligatoire</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12820</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_J_61" value="ECO_ISIC4_J_61">
#         <ns1:Description xml:lang="en">61 - Telecommunications</ns1:Description>
#         <ns1:Description xml:lang="es">61 - Telecomunicaciones</ns1:Description>
#         <ns1:Description xml:lang="fr">61 - Télécommunications</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12740</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_L" value="ECO_ISIC4_L">
#         <ns1:Description xml:lang="en">L. Real estate activities</ns1:Description>
#         <ns1:Description xml:lang="es">L. Actividades inmobiliarias</ns1:Description>
#         <ns1:Description xml:lang="fr">L. Activités immobilières</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12780</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_M" value="ECO_ISIC4_M">
#         <ns1:Description xml:lang="en">M. Professional, scientific and technical activities</ns1:Description>
#         <ns1:Description xml:lang="es">M. Actividades profesionales, científicas y técnicas</ns1:Description>
#         <ns1:Description xml:lang="fr">M. Activités professionnelles, scientifiques et techniques</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12790</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C" value="ECO_ISIC4_C">
#         <ns1:Description xml:lang="en">C. Manufacturing</ns1:Description>
#         <ns1:Description xml:lang="es">C. Industrias manufactureras</ns1:Description>
#         <ns1:Description xml:lang="fr">C. Activités de fabrication</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12530</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_B" value="ECO_ISIC4_B">
#         <ns1:Description xml:lang="en">B. Mining and quarrying</ns1:Description>
#         <ns1:Description xml:lang="es">B. Explotación de minas y canteras</ns1:Description>
#         <ns1:Description xml:lang="fr">B. Activités extractives</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12510</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_Q_86" value="ECO_ISIC4_Q_86">
#         <ns1:Description xml:lang="en">86 - Human health activities</ns1:Description>
#         <ns1:Description xml:lang="es">86 - Actividades de atención de la salud humana</ns1:Description>
#         <ns1:Description xml:lang="fr">86 - Activités relatives à la santé</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12850</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_G_46" value="ECO_ISIC4_G_46">
#         <ns1:Description xml:lang="en">46 - Wholesale trade, except of motor vehicles and motorcycles.</ns1:Description>
#         <ns1:Description xml:lang="es">46 - Comercio al por mayor, excepto el de vehículos automotores y motocicletas</ns1:Description>
#         <ns1:Description xml:lang="fr">46 - Commerce de gros à l'exception des véhicules automobiles et des motocycles</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12660</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_A" value="ECO_ISIC4_A">
#         <ns1:Description xml:lang="en">A. Agriculture; forestry and fishing</ns1:Description>
#         <ns1:Description xml:lang="es">A. Agricultura; ganadería; silvicultura y pesca</ns1:Description>
#         <ns1:Description xml:lang="fr">A. Agriculture; sylviculture et pêche</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12480</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_G_47" value="ECO_ISIC4_G_47">
#         <ns1:Description xml:lang="en">47 - Retail trade, except of motor vehicles and motorcycles</ns1:Description>
#         <ns1:Description xml:lang="es">47 - Comercio al por menor, excepto el de vehículos automotores y motocicletas</ns1:Description>
#         <ns1:Description xml:lang="fr">47 - Commerce de détail à l'exception des véhicules automobiles et des motocycles</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12670</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_G" value="ECO_ISIC4_G">
#         <ns1:Description xml:lang="en">G. Wholesale and retail trade; repair of motor vehicles and motorcycles</ns1:Description>
#         <ns1:Description xml:lang="es">G. Comercio al por mayor y al por menor; reparación de vehículos automotores y motocicletas</ns1:Description>
#         <ns1:Description xml:lang="fr">G. Commerce de gros et de détail, réparations de véhicules automobiles et de motocycles</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12650</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_H_49" value="ECO_ISIC4_H_49">
#         <ns1:Description xml:lang="en">49 - Land transport and transport via pipelines</ns1:Description>
#         <ns1:Description xml:lang="es">49 - Transporte por vía terrestre y transporte por tuberías</ns1:Description>
#         <ns1:Description xml:lang="fr">49 - Transports terrestres, transport par conduites</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12690</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_F" value="ECO_ISIC4_F">
#         <ns1:Description xml:lang="en">F. Construction</ns1:Description>
#         <ns1:Description xml:lang="es">F. Construcción</ns1:Description>
#         <ns1:Description xml:lang="fr">F. Construction</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12630</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_E" value="ECO_ISIC4_E">
#         <ns1:Description xml:lang="en">E. Water supply; sewerage, waste management and remediation activities</ns1:Description>
#         <ns1:Description xml:lang="es">E. Suministro de agua; evacuación de aguas residuales, gestión de desechos y descontaminación</ns1:Description>
#         <ns1:Description xml:lang="fr">E. Distribution d'eau; réseau d'assainissement; gestion des déchets et activités de remise en état</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12610</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_D" value="ECO_ISIC4_D">
#         <ns1:Description xml:lang="en">D. Electricity; gas, steam and air conditioning supply</ns1:Description>
#         <ns1:Description xml:lang="es">D. Suministro de electricidad, gas; vapor y aire acondicionado</ns1:Description>
#         <ns1:Description xml:lang="fr">D. Production et distribution d'électricité; de gaz, de vapeur et climatisation</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12600</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_14" value="ECO_ISIC4_C_14">
#         <ns1:Description xml:lang="en">14 - Manufacture of wearing apparel</ns1:Description>
#         <ns1:Description xml:lang="es">14 - Fabricación de prendas de vestir</ns1:Description>
#         <ns1:Description xml:lang="fr">14 - Fabrication d'articles d'habillement</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12570</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_13" value="ECO_ISIC4_C_13">
#         <ns1:Description xml:lang="en">13 - Manufacture of textiles</ns1:Description>
#         <ns1:Description xml:lang="es">13 - Fabricación de productos textiles</ns1:Description>
#         <ns1:Description xml:lang="fr">13 - Fabrication de textiles</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12560</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_I_55" value="ECO_ISIC4_I_55">
#         <ns1:Description xml:lang="en">55 - Accommodation</ns1:Description>
#         <ns1:Description xml:lang="es">55 - Actividades de alojamiento</ns1:Description>
#         <ns1:Description xml:lang="fr">55 - Hébergement</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12710</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_I_56" value="ECO_ISIC4_I_56">
#         <ns1:Description xml:lang="en">56 - Food and beverage service activities</ns1:Description>
#         <ns1:Description xml:lang="es">56 - Actividades de servicio de comidas y bebidas</ns1:Description>
#         <ns1:Description xml:lang="fr">56 - Activités de services de restauration et de consommation de boissons</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12720</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_10" value="ECO_ISIC4_C_10">
#         <ns1:Description xml:lang="en">10 - Manufacture of food products</ns1:Description>
#         <ns1:Description xml:lang="es">10 - Elaboración de productos alimenticios</ns1:Description>
#         <ns1:Description xml:lang="fr">10 - Fabrication de produits alimentaires</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12540</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_TOTAL" value="ECO_ISIC4_TOTAL">
#         <ns1:Description xml:lang="en">Total</ns1:Description>
#         <ns1:Description xml:lang="es">Total</ns1:Description>
#         <ns1:Description xml:lang="fr">Total</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12470</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_11" value="ECO_ISIC4_C_11">
#         <ns1:Description xml:lang="en">11 - Manufacture of beverages</ns1:Description>
#         <ns1:Description xml:lang="es">11 - Elaboración de bebidas</ns1:Description>
#         <ns1:Description xml:lang="fr">11 - Fabrication de boissons</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12550</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_K_64" value="ECO_ISIC4_K_64">
#         <ns1:Description xml:lang="en">64 - Financial service activities, except insurance and pension funding.</ns1:Description>
#         <ns1:Description xml:lang="es">64 - Actividades de servicios financieros, excepto las de seguros y fondos de pensiones</ns1:Description>
#         <ns1:Description xml:lang="fr">64 - Activités de services financiers, à l'exception des assurances et des caisses de retraite</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12760</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_K_65" value="ECO_ISIC4_K_65">
#         <ns1:Description xml:lang="en">65 - Insurance, reinsurance and pension funding, except compulsory social security.</ns1:Description>
#         <ns1:Description xml:lang="es">65 - Seguros, reaseguros y fondos de pensiones, excepto planes de seguridad social de afiliación obligatoria</ns1:Description>
#         <ns1:Description xml:lang="fr">65 - Activités d'assurances, réassurance et de caisses de retraite, à l'exception de la sécurité sociale obligatoire</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12770</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_31" value="ECO_ISIC4_C_31">
#         <ns1:Description xml:lang="en">31 - Manufacture of furniture</ns1:Description>
#         <ns1:Description xml:lang="es">31 - Fabricación de muebles</ns1:Description>
#         <ns1:Description xml:lang="fr">31 - Fabrication de meubles</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12590</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_A_01" value="ECO_ISIC4_A_01">
#         <ns1:Description xml:lang="en">01 - Crop and animal production, hunting and related service activities.</ns1:Description>
#         <ns1:Description xml:lang="es">01 - Agricultura, ganadería, caza y actividades de servicios conexas</ns1:Description>
#         <ns1:Description xml:lang="fr">01 - Culture et production animale, chasse et activités de services connexes</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12490</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_A_03" value="ECO_ISIC4_A_03">
#         <ns1:Description xml:lang="en">03 - Fishing and aquaculture</ns1:Description>
#         <ns1:Description xml:lang="es">03 - Pesca y acuicultura</ns1:Description>
#         <ns1:Description xml:lang="fr">03 - Pêche et aquaculture</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12500</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_F_41" value="ECO_ISIC4_F_41">
#         <ns1:Description xml:lang="en">41 - Construction of buildings</ns1:Description>
#         <ns1:Description xml:lang="es">41 - Construcción de edificios</ns1:Description>
#         <ns1:Description xml:lang="fr">41 - Construction de bâtiments</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">12640</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">2</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_N_78" value="ECO_ISIC4_N_78">
#         <ns1:Description xml:lang="en">78 - Employment activities</ns1:Description>
#         <ns1:Description xml:lang="es">78 - Actividades de empleo</ns1:Description>
# ...
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_MKT" value="ECO_AGGREGATE_MKT">
#         <ns1:Description xml:lang="en">Trade, Transportation, Accommodation and Food, and Business and Administrative Services</ns1:Description>
#         <ns1:Description xml:lang="es">Comercio, Transporte, Hoteles y Restaurantes, y actividades empresariales</ns1:Description>
#         <ns1:Description xml:lang="fr">Commerce, Transports, Hôtels et restaurants et activités de services aux enterprises</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">13990</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_AGR" value="ECO_AGGREGATE_AGR">
#         <ns1:Description xml:lang="en">Agriculture</ns1:Description>
#         <ns1:Description xml:lang="es">Agricultura</ns1:Description>
#         <ns1:Description xml:lang="fr">Agriculture</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">13930</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_CON" value="ECO_AGGREGATE_CON">
#         <ns1:Description xml:lang="en">Construction</ns1:Description>
#         <ns1:Description xml:lang="es">Construcción</ns1:Description>
#         <ns1:Description xml:lang="fr">Construction</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">13970</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_TOTAL" value="ECO_AGGREGATE_TOTAL">
#         <ns1:Description xml:lang="en">Total</ns1:Description>
#         <ns1:Description xml:lang="es">Total</ns1:Description>
#         <ns1:Description xml:lang="fr">Total</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">13920</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_PUB" value="ECO_AGGREGATE_PUB">
#         <ns1:Description xml:lang="en">Public Administration, Community, Social and other Services and Activities</ns1:Description>
#         <ns1:Description xml:lang="es">Administración pública y servicios y actividades comunales y sociales</ns1:Description>
#         <ns1:Description xml:lang="fr">Administration publique et activités de services collectifs, sociaux et personnels</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">14000</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_AGR" value="ECO_SECTOR_AGR">
#         <ns1:Description xml:lang="en">Agriculture</ns1:Description>
#         <ns1:Description xml:lang="es">Agricultura</ns1:Description>
#         <ns1:Description xml:lang="fr">Agriculture</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">14110</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_TOTAL" value="ECO_SECTOR_TOTAL">
#         <ns1:Description xml:lang="en">Total</ns1:Description>
#         <ns1:Description xml:lang="es">Total</ns1:Description>
#         <ns1:Description xml:lang="fr">Total</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">14100</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_SER" value="ECO_SECTOR_SER">
#         <ns1:Description xml:lang="en">Services</ns1:Description>
#         <ns1:Description xml:lang="es">Servicios</ns1:Description>
#         <ns1:Description xml:lang="fr">Services</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">14140</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_X" value="ECO_SECTOR_X">
#         <ns1:Description xml:lang="en">Not classified</ns1:Description>
#         <ns1:Description xml:lang="es">No clasificados</ns1:Description>
#         <ns1:Description xml:lang="fr">Non classé</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">14150</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_IND" value="ECO_SECTOR_IND">
#         <ns1:Description xml:lang="en">Industry</ns1:Description>
#         <ns1:Description xml:lang="es">Industria</ns1:Description>
#         <ns1:Description xml:lang="fr">Industrie</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">14130</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_TOTNAG_TOTAL" value="ECO_TOTNAG_TOTAL">
#         <ns1:Description xml:lang="en">Total</ns1:Description>
#         <ns1:Description xml:lang="es">Total</ns1:Description>
#         <ns1:Description xml:lang="fr">Total</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">13890</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_TOTNAG_NAG" value="ECO_TOTNAG_NAG">
#         <ns1:Description xml:lang="en">Non-agriculture</ns1:Description>
#         <ns1:Description xml:lang="es">No agrícola</ns1:Description>
#         <ns1:Description xml:lang="fr">Non agricole</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">13910</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGNAG_AGR" value="ECO_AGNAG_AGR">
#         <ns1:Description xml:lang="en">Agriculture</ns1:Description>
#         <ns1:Description xml:lang="es">Agricultura</ns1:Description>
#         <ns1:Description xml:lang="fr">Agriculture</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">13900</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGNAG_TOTAL" value="ECO_AGNAG_TOTAL">
#         <ns1:Description xml:lang="en">Total</ns1:Description>
#         <ns1:Description xml:lang="es">Total</ns1:Description>
#         <ns1:Description xml:lang="fr">Total</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">13890</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGNAG_NAG" value="ECO_AGNAG_NAG">
#         <ns1:Description xml:lang="en">Non-agriculture</ns1:Description>
#         <ns1:Description xml:lang="es">No agrícola</ns1:Description>
#         <ns1:Description xml:lang="fr">Non agricole</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">13910</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#       <ns1:Code urn="urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0)._Z" value="_Z">
#         <ns1:Description xml:lang="en">Not Applicable</ns1:Description>
#         <ns1:Description xml:lang="es">No aplicable en el caso</ns1:Description>
#         <ns1:Description xml:lang="fr">Non Applicable</ns1:Description>
#         <ns1:Annotations>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Sort</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">999999</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Default</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">Y</ns2:AnnotationText>
#           </ns2:Annotation>
#           <ns2:Annotation>
#             <ns2:AnnotationTitle>Level</ns2:AnnotationTitle>
#             <ns2:AnnotationText xml:lang="en">1</ns2:AnnotationText>
#           </ns2:Annotation>
#         </ns1:Annotations>
#       </ns1:Code>
#     </ns1:CodeList>
#   </ns0:CodeLists>
# </ns0:Structure>

# %% [markdown]
# ### Use of the `iter()` function to find elements of interest
#
# `root.iter()` will list all subelements under the root that match the element specified.

# %% [markdown]
# #### Make alist of dictionaries with all the attributes of the `{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code`  elements in the tree:

# %%
codeAttributes = []

for c in root.iter('{http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure}Code'):
    codeAttributes.append(c.attrib)

codeAttributes
# Out:
# [{'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_6',
#   'value': 'ECO_ISIC2_6'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_7',
#   'value': 'ECO_ISIC2_7'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_8',
#   'value': 'ECO_ISIC2_8'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_9',
#   'value': 'ECO_ISIC2_9'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_2',
#   'value': 'ECO_ISIC2_2'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_3',
#   'value': 'ECO_ISIC2_3'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_4',
#   'value': 'ECO_ISIC2_4'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_TOTAL',
#   'value': 'ECO_ISIC2_TOTAL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_5',
#   'value': 'ECO_ISIC2_5'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_0',
#   'value': 'ECO_ISIC2_0'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC2_1',
#   'value': 'ECO_ISIC2_1'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_H',
#   'value': 'ECO_ISIC3_H'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_G',
#   'value': 'ECO_ISIC3_G'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_TOTAL',
#   'value': 'ECO_ISIC3_TOTAL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_F',
#   'value': 'ECO_ISIC3_F'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_E',
#   'value': 'ECO_ISIC3_E'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_D',
#   'value': 'ECO_ISIC3_D'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_C',
#   'value': 'ECO_ISIC3_C'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_B',
#   'value': 'ECO_ISIC3_B'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_A',
#   'value': 'ECO_ISIC3_A'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_O',
#   'value': 'ECO_ISIC3_O'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_P',
#   'value': 'ECO_ISIC3_P'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_M',
#   'value': 'ECO_ISIC3_M'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_N',
#   'value': 'ECO_ISIC3_N'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_K',
#   'value': 'ECO_ISIC3_K'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_L',
#   'value': 'ECO_ISIC3_L'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_I',
#   'value': 'ECO_ISIC3_I'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_J',
#   'value': 'ECO_ISIC3_J'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_X',
#   'value': 'ECO_ISIC3_X'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC3_Q',
#   'value': 'ECO_ISIC3_Q'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_R',
#   'value': 'ECO_ISIC4_R'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_E_36',
#   'value': 'ECO_ISIC4_E_36'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_S',
#   'value': 'ECO_ISIC4_S'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_P',
#   'value': 'ECO_ISIC4_P'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_Q',
#   'value': 'ECO_ISIC4_Q'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_T',
#   'value': 'ECO_ISIC4_T'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_21',
#   'value': 'ECO_ISIC4_C_21'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_U',
#   'value': 'ECO_ISIC4_U'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_J',
#   'value': 'ECO_ISIC4_J'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_K',
#   'value': 'ECO_ISIC4_K'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_H',
#   'value': 'ECO_ISIC4_H'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_I',
#   'value': 'ECO_ISIC4_I'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_N',
#   'value': 'ECO_ISIC4_N'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_O',
#   'value': 'ECO_ISIC4_O'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_J_61',
#   'value': 'ECO_ISIC4_J_61'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_L',
#   'value': 'ECO_ISIC4_L'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_M',
#   'value': 'ECO_ISIC4_M'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C',
#   'value': 'ECO_ISIC4_C'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_B',
#   'value': 'ECO_ISIC4_B'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_Q_86',
#   'value': 'ECO_ISIC4_Q_86'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_G_46',
#   'value': 'ECO_ISIC4_G_46'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_A',
#   'value': 'ECO_ISIC4_A'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_G_47',
#   'value': 'ECO_ISIC4_G_47'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_G',
#   'value': 'ECO_ISIC4_G'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_H_49',
#   'value': 'ECO_ISIC4_H_49'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_F',
#   'value': 'ECO_ISIC4_F'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_E',
#   'value': 'ECO_ISIC4_E'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_D',
#   'value': 'ECO_ISIC4_D'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_14',
#   'value': 'ECO_ISIC4_C_14'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_13',
#   'value': 'ECO_ISIC4_C_13'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_I_55',
#   'value': 'ECO_ISIC4_I_55'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_I_56',
#   'value': 'ECO_ISIC4_I_56'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_10',
#   'value': 'ECO_ISIC4_C_10'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_TOTAL',
#   'value': 'ECO_ISIC4_TOTAL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_11',
#   'value': 'ECO_ISIC4_C_11'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_K_64',
#   'value': 'ECO_ISIC4_K_64'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_K_65',
#   'value': 'ECO_ISIC4_K_65'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_C_31',
#   'value': 'ECO_ISIC4_C_31'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_A_01',
#   'value': 'ECO_ISIC4_A_01'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_A_03',
#   'value': 'ECO_ISIC4_A_03'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_F_41',
#   'value': 'ECO_ISIC4_F_41'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_N_78',
#   'value': 'ECO_ISIC4_N_78'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_ISIC4_X',
#   'value': 'ECO_ISIC4_X'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_MIN',
#   'value': 'ECO_AGGREGATE_MIN'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_MAN',
#   'value': 'ECO_AGGREGATE_MAN'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_X',
#   'value': 'ECO_AGGREGATE_X'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_MANEL',
#   'value': 'ECO_AGGREGATE_MANEL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_MEL',
#   'value': 'ECO_AGGREGATE_MEL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_MKT',
#   'value': 'ECO_AGGREGATE_MKT'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_AGR',
#   'value': 'ECO_AGGREGATE_AGR'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_CON',
#   'value': 'ECO_AGGREGATE_CON'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_TOTAL',
#   'value': 'ECO_AGGREGATE_TOTAL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGGREGATE_PUB',
#   'value': 'ECO_AGGREGATE_PUB'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_AGR',
#   'value': 'ECO_SECTOR_AGR'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_TOTAL',
#   'value': 'ECO_SECTOR_TOTAL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_SER',
#   'value': 'ECO_SECTOR_SER'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_X',
#   'value': 'ECO_SECTOR_X'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_SECTOR_IND',
#   'value': 'ECO_SECTOR_IND'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGNAG_AGR',
#   'value': 'ECO_AGNAG_AGR'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGNAG_TOTAL',
#   'value': 'ECO_AGNAG_TOTAL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_AGNAG_NAG',
#   'value': 'ECO_AGNAG_NAG'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_TOTNAG_TOTAL',
#   'value': 'ECO_TOTNAG_TOTAL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_TOTNAG_NAG',
#   'value': 'ECO_TOTNAG_NAG'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_F',
#   'value': 'ECO_DETAILS_F'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_G',
#   'value': 'ECO_DETAILS_G'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_I',
#   'value': 'ECO_DETAILS_I'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_HJ',
#   'value': 'ECO_DETAILS_HJ'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_K',
#   'value': 'ECO_DETAILS_K'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_O',
#   'value': 'ECO_DETAILS_O'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_P',
#   'value': 'ECO_DETAILS_P'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_Q',
#   'value': 'ECO_DETAILS_Q'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_DE',
#   'value': 'ECO_DETAILS_DE'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_LMN',
#   'value': 'ECO_DETAILS_LMN'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_RSTU',
#   'value': 'ECO_DETAILS_RSTU'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_TOTAL',
#   'value': 'ECO_DETAILS_TOTAL'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_C',
#   'value': 'ECO_DETAILS_C'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_B',
#   'value': 'ECO_DETAILS_B'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0).ECO_DETAILS_A',
#   'value': 'ECO_DETAILS_A'},
#  {'urn': 'urn:sdmx:org.sdmx.infomodel.codelist.Code=ILO:CL_ECO(1.0)._Z',
#   'value': '_Z'}]
