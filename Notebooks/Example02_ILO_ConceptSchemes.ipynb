# %% [markdown]
# # Example 02: Get catalogue of concept schemes
#
# This examples shows how to get the concept scheme available in the ILO's SDMX API (ILOSTAT SDMX Gateway).

# %% [markdown]
# ### Load required libraries

# %%
import xmltodict
import json
import requests 
import xml.etree.ElementTree as ET

# %% [markdown]
# ### Interactive shell

# %%
# https://volderette.de/jupyter-notebook-tip-multiple-outputs/
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# ### Get data from API endpoint and save as xml file on disk

# %%
baseURL = 'http://www.ilo.org/ilostat/sdmx/ws/rest/'

# url of API endpoint
url = baseURL + 'conceptscheme'
url

# creating HTTP response object from given url 
resp = requests.get(url) 

# saving the xml message into an xml file 
with open('test.xml', 'wb') as f: 
    f.write(resp.content)
# Out:
# 'http://www.ilo.org/ilostat/sdmx/ws/rest/conceptscheme'
# 67337

# %% [markdown]
# ### Open xml file using `xmltodict.parse`
# This will create an object consisting of various nested ordered dictionaries. Every node of the XML tree is an ordered dictionary of key-value pairs. The root of the XML tree is an ordered dictionary itself.

# %%
xmlFile = 'test.xml'

with open(xmlFile) as fd:
    doc = xmltodict.parse(fd.read())

# %% [markdown]
# ### Drill down to level 3, which contains the actual code list

# %%
print('---Root:')
len(doc)
rootKey = list(doc.keys())[0]
rootKey

print('---Level 1:')
level1 = doc[rootKey]
len(level1)
level1Keys = list(level1.keys())
level1Keys

print('---Level 2 / mes:Concepts')
level2 = level1['mes:Concepts']
len(level2)
level2Keys = list(level2.keys())
level2Keys

print('---Level 3 / str:ConceptScheme')
level3 = level2['str:ConceptScheme']
len(level3)

level3[0].keys()
level3[1].keys()
level3[2].keys()
# Out:
# ---Root:
# 1
# 'mes:Structure'
# ---Level 1:
# 4
# ['@xmlns:mes', '@xmlns:str', 'mes:Header', 'mes:Concepts']
# ---Level 2 / mes:Concepts
# 1
# ['str:ConceptScheme']
# ---Level 3 / str:ConceptScheme
# 4
# odict_keys(['@agencyID', '@id', '@urn', '@version', '@isFinal', 'str:Name', 'str:Concept'])
# odict_keys(['@agencyID', '@id', '@urn', '@version', '@isFinal', 'str:Name', 'str:Concept'])
# odict_keys(['@agencyID', '@id', '@urn', '@version', '@isFinal', 'str:Name', 'str:Concept'])

# %% [markdown]
# ### Collect the concept scheme information in a dictionary

# %%
conceptSchemes = []

for cs in level3:
    conceptScheme = {}

    conceptScheme['agencyId'] = cs['@agencyID']
    conceptScheme['id'] = cs['@id']
    conceptScheme['urn'] = cs['@urn']
    conceptScheme['version'] = cs['@version']
    conceptScheme['isFinal'] = cs['@isFinal']

    conceptScheme['nameEN'] = cs['str:Name']['#text']
    
    conceptScheme['concepts'] = []

    
    # cs['str:Concept']
    
    for x in cs['str:Concept']:
        
        concept = {}
        concept['id'] = x['@id']
        concept['urn'] = x['@urn']
        # the following are defined only if the concept is coded:
        if '@coreRepresentation' in x.keys():
            concept['coreRepresentation'] = x['@coreRepresentation']
        else:
            concept['coreRepresentation'] = None
            
        if '@coreRepresentationAgency' in x.keys():
            concept['coreRepresentationAgency'] = x['@coreRepresentationAgency']
        else:
            concept['coreRepresentationAgency'] = None
        
        
        concept['nameEN'] = None
        concept['nameES'] = None
        concept['nameFR'] = None
        
        conceptName = x['str:Name']
        
        if isinstance(conceptName, list):
            for x2 in conceptName:
                if x2['@xml:lang'] == 'en':
                    concept['nameEN'] = x2['#text']
                if x2['@xml:lang'] == 'es':
                    concept['nameES'] = x2['#text']
                if x2['@xml:lang'] == 'fr':
                    concept['nameFR'] = x2['#text']
        else:
            if conceptName['@xml:lang'] == 'en':
                concept['nameEN'] = conceptName['#text']
            if conceptName['@xml:lang'] == 'es':
                concept['nameES'] = conceptName['#text']
            if conceptName['@xml:lang'] == 'fr':
                concept['nameFR'] = conceptName['#text']
            
    
        
        conceptScheme['concepts'].append(concept)
    
    conceptSchemes.append(conceptScheme)

conceptSchemes
# Out:
# [{'agencyId': 'ILO',
#   'id': 'CS_CLASSIF_TYPE',
#   'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.ConceptScheme=ILO:CS_CLASSIF_TYPE(1.0)',
#   'version': '1.0',
#   'isFinal': 'true',
#   'nameEN': 'Classifications',
#   'concepts': [{'id': 'CLASSIF_SEX',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_SEX',
#     'coreRepresentation': 'CL_SEX',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Sex',
#     'nameES': 'Sexo',
#     'nameFR': 'Sexe'},
#    {'id': 'CLASSIF_AGE',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_AGE',
#     'coreRepresentation': 'CL_AGE',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Age',
#     'nameES': 'Edad',
#     'nameFR': 'Age'},
#    {'id': 'CLASSIF_EDU',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_EDU',
#     'coreRepresentation': 'CL_EDU',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Education',
#     'nameES': 'EducaciÃ³n',
#     'nameFR': 'Education'},
#    {'id': 'CLASSIF_GEO',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_GEO',
#     'coreRepresentation': 'CL_GEO',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Area type',
#     'nameES': 'Tipo de Ã¡rea',
#     'nameFR': 'Type de zone'},
#    {'id': 'CLASSIF_STE',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_STE',
#     'coreRepresentation': 'CL_STE',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Status in employment',
#     'nameES': 'SituaciÃ³n en el empleo',
#     'nameFR': 'Situation dans la profession'},
#    {'id': 'CLASSIF_ECO',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_ECO',
#     'coreRepresentation': 'CL_ECO',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Economic activity',
#     'nameES': 'Actividad econÃ³mica',
#     'nameFR': 'ActivitÃ© Ã©conomique'},
#    {'id': 'CLASSIF_OCU',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_OCU',
#     'coreRepresentation': 'CL_OCU',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Occupation',
#     'nameES': 'OcupaciÃ³n',
#     'nameFR': 'Profession'},
#    {'id': 'CLASSIF_INS',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_INS',
#     'coreRepresentation': 'CL_INS',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Sector',
#     'nameES': 'Sector',
#     'nameFR': 'Secteur'},
#    {'id': 'CLASSIF_HOW',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_HOW',
#     'coreRepresentation': 'CL_HOW',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Hour bands',
#     'nameES': 'Tramos de horas',
#     'nameFR': 'Tranches horaires'},
#    {'id': 'CLASSIF_DUR',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_DUR',
#     'coreRepresentation': 'CL_DUR',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Duration',
#     'nameES': 'DuraciÃ³n',
#     'nameFR': 'DurÃ©e'},
#    {'id': 'CLASSIF_CAT',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_CAT',
#     'coreRepresentation': 'CL_CAT',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Category of unemployed',
#     'nameES': 'CategorÃ\xada de desempleado',
#     'nameFR': 'CatÃ©gorie de chÃ´meur'},
#    {'id': 'CLASSIF_QTL',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_QTL',
#     'coreRepresentation': 'CL_QTL',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Quantile',
#     'nameES': 'Cuantil',
#     'nameFR': 'Quantile'},
#    {'id': 'CLASSIF_INJ',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_INJ',
#     'coreRepresentation': 'CL_INJ',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Occupational injuries',
#     'nameES': 'Lesiones Profesionales',
#     'nameFR': 'LÃ©sions professionnelles'},
#    {'id': 'CLASSIF_COI',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_COI',
#     'coreRepresentation': 'CL_COI',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'COICOP',
#     'nameES': 'CCIF',
#     'nameFR': 'COICOP'},
#    {'id': 'CLASSIF_NOC',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_NOC',
#     'coreRepresentation': 'CL_NOC',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'No classification',
#     'nameES': 'Sin clasificaciÃ³n',
#     'nameFR': 'Pas de classification'},
#    {'id': 'CLASSIF_LMS',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_LMS',
#     'coreRepresentation': 'CL_LMS',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Labour market status',
#     'nameES': 'SituaciÃ³n en el mercado de trabajo',
#     'nameFR': 'Situation sur le marchÃ© du travail'},
#    {'id': 'CLASSIF_STU',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_STU',
#     'coreRepresentation': 'CL_STU',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Educational attendance',
#     'nameES': 'Asistencia educativa',
#     'nameFR': 'FrÃ©quentation scolaire'},
#    {'id': 'CLASSIF_JOB',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_JOB',
#     'coreRepresentation': 'CL_JOB',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Job',
#     'nameES': 'Trabajo',
#     'nameFR': 'Travail'},
#    {'id': 'CLASSIF_SOC',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_SOC',
#     'coreRepresentation': 'CL_SOC',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Benefits schemes',
#     'nameES': 'Typo de los prestaciones',
#     'nameFR': 'Type de prestations'},
#    {'id': 'CLASSIF_MIG',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_MIG',
#     'coreRepresentation': 'CL_MIG',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Migrant status',
#     'nameES': 'SituaciÃ³n de migrante',
#     'nameFR': 'Statut de migrant'},
#    {'id': 'CLASSIF_COU',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_COU',
#     'coreRepresentation': 'CL_COU',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Country',
#     'nameES': 'PaÃ\xads',
#     'nameFR': 'Pays'},
#    {'id': 'CLASSIF_EXP',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_EXP',
#     'coreRepresentation': 'CL_EXP',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Expenditure',
#     'nameES': 'Gastos',
#     'nameFR': 'DÃ©penses'},
#    {'id': 'CLASSIF_IFL',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_IFL',
#     'coreRepresentation': 'CL_IFL',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Type of informal employment',
#     'nameES': 'Tipo de empleo informal',
#     'nameFR': "Type d'emploi informel"},
#    {'id': 'CLASSIF_GOV',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_GOV',
#     'coreRepresentation': 'CL_GOV',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': "Gov't level",
#     'nameES': 'Nivel del gobierno',
#     'nameFR': 'Niveau de gouv.'},
#    {'id': 'CLASSIF_DSB',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_DSB',
#     'coreRepresentation': 'CL_DSB',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Disability status',
#     'nameES': 'SituaciÃ³n en tÃ©rminos de discapacidad',
#     'nameFR': 'Situation en termes dâ€™handicap'},
#    {'id': 'CLASSIF_CLA',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_CLA',
#     'coreRepresentation': 'CL_CLA',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Class',
#     'nameES': 'Clase',
#     'nameFR': 'Classe'},
#    {'id': 'CLASSIF_CUR',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_CUR',
#     'coreRepresentation': 'CL_CUR',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Currency',
#     'nameES': 'Divisa',
#     'nameFR': 'Devise'},
#    {'id': 'CLASSIF_CDS',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_CDS',
#     'coreRepresentation': 'CL_CDS',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Country of destination',
#     'nameES': 'PaÃ\xads de destino',
#     'nameFR': 'Pays de destination'},
#    {'id': 'CLASSIF_CPR',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_CPR',
#     'coreRepresentation': 'CL_CPR',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Country of previous residence',
#     'nameES': 'PaÃ\xads de residencia anterior',
#     'nameFR': 'Pays de rÃ©sidence prÃ©cÃ©dente'},
#    {'id': 'CLASSIF_CRS',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_CRS',
#     'coreRepresentation': 'CL_CRS',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Country of residence',
#     'nameES': 'PaÃ\xads de residencia',
#     'nameFR': 'Pays de rÃ©sidence'},
#    {'id': 'CLASSIF_CBR',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_CBR',
#     'coreRepresentation': 'CL_CBR',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Place of birth',
#     'nameES': 'Lugar de nacimiento',
#     'nameFR': 'Lieu de naissance'},
#    {'id': 'CLASSIF_CCT',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_CLASSIF_TYPE(1.0).CLASSIF_CCT',
#     'coreRepresentation': 'CL_CCT',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Citizenship',
#     'nameES': 'Ciudadania',
#     'nameFR': 'CitoyennetÃ©'}]},
#  {'agencyId': 'ILO',
#   'id': 'CS_DISSEM',
#   'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.ConceptScheme=ILO:CS_DISSEM(1.0)',
#   'version': '1.0',
#   'isFinal': 'true',
#   'nameEN': 'DISSEM Concepts',
#   'concepts': [{'id': 'INDICATOR',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).INDICATOR',
#     'coreRepresentation': 'CL_INDICATOR',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Indicator',
#     'nameES': 'Indicador',
#     'nameFR': 'Indicateur'},
#    {'id': 'DECIMAL_POSITION',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).DECIMAL_POSITION',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Decimal Position',
#     'nameES': 'Posiciones decimales',
#     'nameFR': 'Positions dÃ©cimales'},
#    {'id': 'INDICATOR_SORT_ORDER',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).INDICATOR_SORT_ORDER',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Indicator Sort Order',
#     'nameES': 'Orden del indicador',
#     'nameFR': 'Ordre de tri de lindicateur'},
#    {'id': 'INDICATOR_DESCRIPTION',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).INDICATOR_DESCRIPTION',
#     'coreRepresentation': 'CL_INDICATOR_DESCRIPTION',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Indicator Description',
#     'nameES': 'DescripciÃ³n del indicador',
#     'nameFR': 'Description de lindicateur'},
#    {'id': 'SOURCE',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SOURCE',
#     'coreRepresentation': 'CL_SOURCE',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Source',
#     'nameES': 'Fuente',
#     'nameFR': 'Source'},
#    {'id': 'SOURCE_DESCRIPTION',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SOURCE_DESCRIPTION',
#     'coreRepresentation': 'CL_SOURCE_DESCRIPTION',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Source Description',
#     'nameES': 'DescripciÃ³n de la fuente',
#     'nameFR': 'Description de la source'},
#    {'id': 'SOURCE_SORT_ORDER',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SOURCE_SORT_ORDER',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Source Sort Order',
#     'nameES': 'Orden de la fuente',
#     'nameFR': 'Ordre de tri de la source'},
#    {'id': 'R_VAR_COMPLEMENT',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).R_VAR_COMPLEMENT',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Represented Variable Complement',
#     'nameES': 'Complemento de Variable representada',
#     'nameFR': 'Complement de variable representÅ½e'},
#    {'id': 'SUBJECT1',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SUBJECT1',
#     'coreRepresentation': 'CL_SUBJECT',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Subject #1',
#     'nameES': 'Tema #1',
#     'nameFR': 'ThÃ¨me #1'},
#    {'id': 'SUBJECT_SORT_ORDER1',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SUBJECT_SORT_ORDER1',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Subject Sort Order #1',
#     'nameES': 'Orden del tema #1',
#     'nameFR': 'Ordre de tri du thÃ¨me #1'},
#    {'id': 'SUBJECT_DESCRIPTION1',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SUBJECT_DESCRIPTION1',
#     'coreRepresentation': 'CL_SUBJECT_DESCRIPTION',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Subject Description #1',
#     'nameES': 'DescripciÃ³n del tema #1',
#     'nameFR': 'Description du thÃ¨me #1'},
#    {'id': 'SUBJECT2',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SUBJECT2',
#     'coreRepresentation': 'CL_SUBJECT',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Subject #2',
#     'nameES': 'Tema #2',
#     'nameFR': 'ThÃ¨me #2'},
#    {'id': 'SUBJECT_SORT_ORDER2',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SUBJECT_SORT_ORDER2',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Subject Sort Order #2',
#     'nameES': 'Orden del tema #2',
#     'nameFR': 'Ordre de tri du thÃ¨me #2'},
#    {'id': 'SUBJECT_DESCRIPTION2',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SUBJECT_DESCRIPTION2',
#     'coreRepresentation': 'CL_SUBJECT_DESCRIPTION',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Subject Description #2',
#     'nameES': 'DescripciÃ³n del tema #2',
#     'nameFR': 'Description du thÃ¨me #2'},
#    {'id': 'SUBJECT3',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SUBJECT3',
#     'coreRepresentation': 'CL_SUBJECT',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Subject #3',
#     'nameES': 'Tema #3',
#     'nameFR': 'ThÃ¨me #3'},
#    {'id': 'SUBJECT_SORT_ORDER3',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SUBJECT_SORT_ORDER3',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Subject Sort Order #3',
#     'nameES': 'Orden del tema #3',
#     'nameFR': 'Ordre de tri du thÃ¨me #3'},
#    {'id': 'SUBJECT_DESCRIPTION3',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_DISSEM(1.0).SUBJECT_DESCRIPTION3',
#     'coreRepresentation': 'CL_SUBJECT_DESCRIPTION',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Subject Description #3',
#     'nameES': 'DescripciÃ³n del tema #3',
#     'nameFR': 'Description du thÃ¨me #3'}]},
#  {'agencyId': 'ILO',
#   'id': 'CS_ILOSTAT',
#   'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.ConceptScheme=ILO:CS_ILOSTAT(1.0)',
#   'version': '1.0',
#   'isFinal': 'true',
#   'nameEN': 'ILOSTAT Concepts',
#   'concepts': [{'id': 'COLLECTION',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).COLLECTION',
#     'coreRepresentation': 'CL_COLLECTION',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Data collection',
#     'nameES': 'ColecciÃ³n de Datos',
#     'nameFR': 'Collectes de donnÃ©es'},
#    {'id': 'COUNTRY',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).COUNTRY',
#     'coreRepresentation': 'CL_COUNTRY',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Country',
#     'nameES': 'PaÃ\xads',
#     'nameFR': 'Pays'},
#    {'id': 'FREE_TEXT_NOTE',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).FREE_TEXT_NOTE',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Free text note; should be used when a note cannot be coded or in the case of multiple values for one note type',
#     'nameES': 'Nota libre: debe ser usada cuando no es posible codificar una nota o en caso de mÃºltiples valores para un tipo de nota',
#     'nameFR': 'Note libre: Ã€ utiliser lorsque la note ne peut pas Ãªtre codÃ©e ou lorsquil y a plusieurs valeurs pour un mÃªme type de notes'},
#    {'id': 'FREQ',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).FREQ',
#     'coreRepresentation': 'CL_FREQ',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Frequency',
#     'nameES': 'Frecuencia',
#     'nameFR': 'FrÃ©quence'},
#    {'id': 'OBS_VALUE',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).OBS_VALUE',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Observation value',
#     'nameES': 'Valor observado',
#     'nameFR': 'Valeur observÃ©e'},
#    {'id': 'TIME_PERIOD',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).TIME_PERIOD',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Time period',
#     'nameES': 'PerÃ\xadodo',
#     'nameFR': 'PÃ©riode de temps'},
#    {'id': 'SURVEY',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).SURVEY',
#     'coreRepresentation': 'CL_SURVEY',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Survey',
#     'nameES': 'Encuesta',
#     'nameFR': 'EnquÃªte'},
#    {'id': 'VALUE_STATUS',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).VALUE_STATUS',
#     'coreRepresentation': 'CL_VALUE_STATUS',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Value status',
#     'nameES': 'Estado del valor',
#     'nameFR': 'Ã‰tat de la valeur'},
#    {'id': 'UNIT_MEAS_TYPE',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).UNIT_MEAS_TYPE',
#     'coreRepresentation': 'CL_UNIT_MEASURE_TYPE',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Unit of measure type',
#     'nameES': 'Tipo de unidad de medida',
#     'nameFR': 'Type dunitÃ© de mesure'},
#    {'id': 'UNIT_MEAS',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).UNIT_MEAS',
#     'coreRepresentation': 'CL_UNIT_MEASURE',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Unit of measure',
#     'nameES': 'Unidad de medida',
#     'nameFR': 'UnitÃ© de mesure'},
#    {'id': 'UNIT_MULT',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).UNIT_MULT',
#     'coreRepresentation': 'CL_UNIT_MULT',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Unit multiplier',
#     'nameES': 'Multiplicador',
#     'nameFR': 'Multiplicateur'},
#    {'id': 'REPRESENTED_VARIABLE',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).REPRESENTED_VARIABLE',
#     'coreRepresentation': 'CL_REPRESENTED_VARIABLE',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Represented Variable',
#     'nameES': 'Variable representada',
#     'nameFR': 'Variable representÃ©e'},
#    {'id': 'TIME_FORMAT',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_ILOSTAT(1.0).TIME_FORMAT',
#     'coreRepresentation': 'CL_TIME_FORMAT',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Time format',
#     'nameES': 'Formato de Tiempo',
#     'nameFR': 'Format utilisÃ©'}]},
#  {'agencyId': 'ILO',
#   'id': 'CS_NOTE_TYPE',
#   'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.ConceptScheme=ILO:CS_NOTE_TYPE(1.0)',
#   'version': '1.0',
#   'isFinal': 'true',
#   'nameEN': 'Note types',
#   'concepts': [{'id': 'MET_T28',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T28',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Base year for indexes',
#     'nameES': 'AÃ±o base para los Ã\xadndices',
#     'nameFR': 'AnnÃ©e de base pour les indices'},
#    {'id': 'MET_T29',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T29',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Base year for weights',
#     'nameES': 'AÃ±o base para las ponderaciones',
#     'nameFR': 'AnnÃ©e de base pour les poids'},
#    {'id': 'MET_T30',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T30',
#     'coreRepresentation': 'CL_CURRENCY',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Local currency',
#     'nameES': 'Moneda local',
#     'nameFR': 'Monnaie locale'},
#    {'id': 'MET_T31',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T31',
#     'coreRepresentation': 'CL_NOTE_T31',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Trade union membership coverage',
#     'nameES': 'Cobertura de la sindicalizaciÃ³n',
#     'nameFR': "Couverture de l'affiliation syndicale"},
#    {'id': 'MET_T32',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T32',
#     'coreRepresentation': 'CL_NOTE_T32',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Collective bargaining coverage',
#     'nameES': 'Cobertura de las negociaciones colectivas',
#     'nameFR': 'Couverture des nÃ©gociations collectives'},
#    {'id': 'MET_I9',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I9',
#     'coreRepresentation': 'CL_NOTE_I9',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Unit',
#     'nameES': 'Unidad',
#     'nameFR': 'UnitÃ©'},
#    {'id': 'MET_S11',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S11',
#     'coreRepresentation': 'CL_NOTE_S11',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Temporary change in source',
#     'nameES': 'Cambio Temporal en la fuente',
#     'nameFR': 'Changement temporaire de la source'},
#    {'id': 'MET_T34',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T34',
#     'coreRepresentation': 'CL_NOTE_T34',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Components of earnings/wages',
#     'nameES': 'Componentes de las ganancias/los salarios',
#     'nameFR': 'Composantes des gains/salaires'},
#    {'id': 'OVN_C7',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C7',
#     'coreRepresentation': 'CL_NOTE_C7',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nonstandard duration of unemployment',
#     'nameES': 'DuraciÃ³n del desempleo no estÃ¡ndar',
#     'nameFR': 'DurÃ©e du chÃ´mage non standard'},
#    {'id': 'MET_I11',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I11',
#     'coreRepresentation': 'CL_NOTE_I11',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Break in series',
#     'nameES': 'Ruptura en la serie',
#     'nameFR': 'Rupture de sÃ©rie'},
#    {'id': 'MET_I13',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I13',
#     'coreRepresentation': 'CL_NOTE_I13',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Remarks',
#     'nameES': 'Observaciones',
#     'nameFR': 'Remarques'},
#    {'id': 'MET_T33',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T33',
#     'coreRepresentation': 'CL_NOTE_T33',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Working time concept',
#     'nameES': 'Concepto de tiempo de trabajo',
#     'nameFR': 'Notion de temps de travail'},
#    {'id': 'MET_I12',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I12',
#     'coreRepresentation': 'CL_NOTE_I12',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Frequency',
#     'nameES': 'Frecuencia',
#     'nameFR': 'FrÃ©quence'},
#    {'id': 'OVN_C1',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C1',
#     'coreRepresentation': 'CL_NOTE_C1',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nonstandard COICOP classification',
#     'nameES': 'ClasificaciÃ³n CCIF no estÃ¡ndar',
#     'nameFR': 'Classification COICOP non standard'},
#    {'id': 'OVN_C4',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C4',
#     'coreRepresentation': 'CL_NOTE_C4',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nonstandard occupation',
#     'nameES': 'OcupaciÃ³n no estÃ¡ndar',
#     'nameFR': 'Profession non standard'},
#    {'id': 'OVN_C6',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C6',
#     'coreRepresentation': 'CL_NOTE_C6',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nonstandard age group',
#     'nameES': 'Grupo de edad no estÃ¡ndar',
#     'nameFR': "Groupe d'Ã¢ge non standard"},
#    {'id': 'OVN_C2',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C2',
#     'coreRepresentation': 'CL_NOTE_C2',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nonstandard status in employment group',
#     'nameES': 'Grupo situaciÃ³n en el empleo no estÃ¡ndar',
#     'nameFR': 'Groupe de la situation dans la profession non standard'},
#    {'id': 'OVN_C3',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C3',
#     'coreRepresentation': 'CL_NOTE_C3',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nonstandard education level',
#     'nameES': 'Nivel de educaciÃ³n no estÃ¡ndar',
#     'nameFR': "Niveau de l'Ã©ducation non standard"},
#    {'id': 'OVN_C5',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C5',
#     'coreRepresentation': 'CL_NOTE_C5',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nonstandard economic activity',
#     'nameES': 'Actividad econÃ³mica no estÃ¡ndar',
#     'nameFR': 'ActivitÃ© Ã©conomique non standard'},
#    {'id': 'MET_S3',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S3',
#     'coreRepresentation': 'CL_NOTE_S3',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Data reference period',
#     'nameES': 'PerÃ\xadodo de referencia de los datos',
#     'nameFR': 'PÃ©riode de rÃ©fÃ©rence des donnÃ©es'},
#    {'id': 'MET_S4',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S4',
#     'coreRepresentation': 'CL_NOTE_S4',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Geographical coverage',
#     'nameES': 'Cobertura geogrÃ¡fica',
#     'nameFR': 'Couverture gÃ©ographique'},
#    {'id': 'MET_S5',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S5',
#     'coreRepresentation': 'CL_NOTE_S5',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Population coverage',
#     'nameES': 'Cobertura de la poblaciÃ³n',
#     'nameFR': 'Couverture de la population'},
#    {'id': 'MET_S6',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S6',
#     'coreRepresentation': 'CL_NOTE_S6',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Establishment size coverage',
#     'nameES': 'Cobertura de tamaÃ±o de los establecimientos',
#     'nameFR': 'Couverture des tailles des Ã©tablissements'},
#    {'id': 'MET_S7',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S7',
#     'coreRepresentation': 'CL_NOTE_S7',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Institutional sector coverage',
#     'nameES': 'Cobertura de sectores institucionales',
#     'nameFR': 'Couverture des secteurs institutionnels'},
#    {'id': 'MET_S8',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S8',
#     'coreRepresentation': 'CL_NOTE_S8',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Economic activity coverage',
#     'nameES': 'Cobertura de las actividades econÃ³micas',
#     'nameFR': 'Couverture des activitÃ©s Ã©conomiques'},
#    {'id': 'MET_S9',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S9',
#     'coreRepresentation': 'CL_NOTE_S9',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Reference group coverage',
#     'nameES': 'Cobertura del grupo de referencia',
#     'nameFR': 'Couverture du groupe de rÃ©fÃ©rence'},
#    {'id': 'MET_S10',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S10',
#     'coreRepresentation': 'CL_NOTE_S10',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'System of national accounts',
#     'nameES': 'Sistema de cuentas nacionales',
#     'nameFR': 'SystÃ¨me de comptabilitÃ© nationale'},
#    {'id': 'MET_T2',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T2',
#     'coreRepresentation': 'CL_NOTE_T2',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Age coverage - minimum age',
#     'nameES': 'Cobertura de edad - edad mÃ\xadnima',
#     'nameFR': "Couverture d'Ã¢ge - Ã¢ge minimum"},
#    {'id': 'MET_T3',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T3',
#     'coreRepresentation': 'CL_NOTE_T3',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Age coverage - maximum age',
#     'nameES': 'Cobertura de edad - edad mÃ¡xima',
#     'nameFR': "Couverture d'Ã¢ge - Ã¢ge maximum"},
#    {'id': 'MET_T4',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T4',
#     'coreRepresentation': 'CL_NOTE_T4',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Threshold used to define time-related underemployment',
#     'nameES': 'LÃ\xadmite utilizado para definir el subempleo por insuficiencia de horas',
#     'nameFR': 'Seuil utilisÃ© pour dÃ©finir le sous-emploi liÃ© Ã\xa0 la durÃ©e du travail'},
#    {'id': 'MET_T5',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T5',
#     'coreRepresentation': 'CL_NOTE_T5',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Unemployment definition',
#     'nameES': 'DefiniciÃ³n de la desocupaciÃ³n',
#     'nameFR': 'DÃ©finition du chÃ´mage'},
#    {'id': 'MET_T6',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T6',
#     'coreRepresentation': 'CL_NOTE_T6',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Labour cost concept',
#     'nameES': 'Concepto del costo de la mano de obra',
#     'nameFR': "Concept de coÃ»t de la main-d'oeuvre"},
#    {'id': 'MET_T7',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T7',
#     'coreRepresentation': 'CL_NOTE_T7',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Time unit',
#     'nameES': 'Unidad de tiempo',
#     'nameFR': 'UnitÃ© de temps'},
#    {'id': 'MET_T8',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T8',
#     'coreRepresentation': 'CL_NOTE_T8',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Central tendency measure',
#     'nameES': 'Medida de tendencia central',
#     'nameFR': 'Mesure de tendance centrale'},
#    {'id': 'MET_T9',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T9',
#     'coreRepresentation': 'CL_NOTE_T9',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Value type',
#     'nameES': 'Tipo de valor',
#     'nameFR': 'Type de valeur'},
#    {'id': 'MET_T10',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T10',
#     'coreRepresentation': 'CL_NOTE_T10',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Accounting concept',
#     'nameES': 'Concepto contable',
#     'nameFR': 'Concept comptable'},
#    {'id': 'MET_T11',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T11',
#     'coreRepresentation': 'CL_NOTE_T11',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Job coverage',
#     'nameES': 'Cobertura de los empleos',
#     'nameFR': 'Couverture des emplois'},
#    {'id': 'MET_T12',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T12',
#     'coreRepresentation': 'CL_NOTE_T12',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Working time arrangement coverage',
#     'nameES': 'Cobertura del ordenamiento del tiempo de trabajo',
#     'nameFR': 'Couverture des accords sur le temps de travail'},
#    {'id': 'MET_T13',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T13',
#     'coreRepresentation': 'CL_NOTE_T13',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Coverage of occupational injuries',
#     'nameES': 'Cobertura de lesiones profesionales',
#     'nameFR': 'Couverture des lÃ©sions professionnelles'},
#    {'id': 'MET_T14',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T14',
#     'coreRepresentation': 'CL_NOTE_T14',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Type of cases of occupational injuries',
#     'nameES': 'Tipo de casos de lesiones profesionales',
#     'nameFR': 'Type de cas des lÃ©sions professionnelles'},
#    {'id': 'MET_T16',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T16',
#     'coreRepresentation': 'CL_NOTE_T16',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Labour dispute actions coverage',
#     'nameES': 'Cobertura de las acciones de los conflictos de trabajo',
#     'nameFR': 'Couverture des actions liÃ©es aux conflits du travail'},
#    {'id': 'MET_T17',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T17',
#     'coreRepresentation': 'CL_NOTE_T17',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Lower limit on coverage of strikes and lockouts',
#     'nameES': 'LÃ\xadmite inferior de cobertura de huelgas y cierres patronales',
#     'nameFR': 'Seuil infÃ©rieur pour la couverture des grÃ¨ves et lock-outs'},
#    {'id': 'MET_T18',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T18',
#     'coreRepresentation': 'CL_NOTE_T18',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Poverty threshold reporting unit',
#     'nameES': 'Unidad de reporte del umbral de pobreza',
#     'nameFR': 'UnitÃ© de rapport du seuil de pauvretÃ©'},
#    {'id': 'MET_T19',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T19',
#     'coreRepresentation': 'CL_NOTE_T19',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Income distribution measurement unit',
#     'nameES': 'Unidad de medida de la distribuciÃ³n del ingreso',
#     'nameFR': 'UnitÃ© de mesure de la distribution du revenu'},
#    {'id': 'MET_T20',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T20',
#     'coreRepresentation': 'CL_NOTE_T20',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Poverty line method',
#     'nameES': 'MÃ©todo de lÃ\xadnea de pobreza',
#     'nameFR': 'MÃ©thode utilisÃ©e pour le seuil de pauvretÃ©'},
#    {'id': 'MET_T21',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T21',
#     'coreRepresentation': 'CL_NOTE_T21',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Income (or expenditure) components',
#     'nameES': 'Componentes del ingreso (o del gasto)',
#     'nameFR': 'Composants du revenu (ou des dÃ©penses)'},
#    {'id': 'MET_T22',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T22',
#     'coreRepresentation': 'CL_NOTE_T22',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Absolute vs. Relative value of income distribution',
#     'nameES': 'DistribuciÃ³n del ingreso en valor absoluto o relativo',
#     'nameFR': 'Valeur absolue ou relative de la distribution du revenu'},
#    {'id': 'MET_T23',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T23',
#     'coreRepresentation': 'CL_NOTE_T23',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Reference period of trade union membership',
#     'nameES': 'PerÃ\xadodo de referencia para afiliaciones a sindicatos',
#     'nameFR': "PÃ©riode de rÃ©fÃ©rence pour l'adhÃ©sion aux syndicats"},
#    {'id': 'MET_T24',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T24',
#     'coreRepresentation': 'CL_NOTE_T24',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Reference period of collective bargaining coverage',
#     'nameES': 'PerÃ\xadodo de referencia para la cobertura de la negociaciÃ³n colectiva',
#     'nameFR': 'PÃ©riode de rÃ©fÃ©rence pour la couverture des nÃ©gociations collectives'},
#    {'id': 'MET_T25',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T25',
#     'coreRepresentation': 'CL_NOTE_T25',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Measure of output',
#     'nameES': 'Medida del producto',
#     'nameFR': 'Mesure de la production'},
#    {'id': 'MET_T26',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T26',
#     'coreRepresentation': 'CL_NOTE_T26',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Type of prices',
#     'nameES': 'Tipo de precios',
#     'nameFR': 'Type de prix'},
#    {'id': 'MET_T27',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T27',
#     'coreRepresentation': 'CL_NOTE_T27',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Employment income components',
#     'nameES': 'Componentes del ingreso del empleo',
#     'nameFR': "Composants du revenu de l'emploi"},
#    {'id': 'MET_I4',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I4',
#     'coreRepresentation': 'CL_NOTE_I4',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Type of rate',
#     'nameES': 'Tipo de tasa',
#     'nameFR': 'Type de taux'},
#    {'id': 'MET_I5',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I5',
#     'coreRepresentation': 'CL_NOTE_I5',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Time unit for measuring time lost',
#     'nameES': 'Unidad de tiempo para medir el tiempo perdido',
#     'nameFR': 'UnitÃ© de temps pour mesurer le temps perdu'},
#    {'id': 'MET_I7',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I7',
#     'coreRepresentation': 'CL_NOTE_I7',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Workers involved',
#     'nameES': 'Trabajadores implicados',
#     'nameFR': 'Travailleurs impliquÃ©s'},
#    {'id': 'MET_S1',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S1',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Survey name (without year)',
#     'nameES': 'Nombre de la encuesta (sin aÃ±o)',
#     'nameFR': "Nom de l'enquÃªte (sans l'annÃ©e)"},
#    {'id': 'MET_I1',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I1',
#     'coreRepresentation': 'CL_NOTE_I1',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Time period for occurrence of death',
#     'nameES': 'PerÃ\xadodo de tiempo para las muertes acaecidas',
#     'nameFR': 'PÃ©riode de temps pour la survenue de la mort'},
#    {'id': 'MET_I2',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I2',
#     'coreRepresentation': 'CL_NOTE_I2',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Minimum period of absence from work',
#     'nameES': 'PerÃ\xadodo mÃ\xadnimo de ausencia del trabajo',
#     'nameFR': "DurÃ©e minimale d'absence du travail"},
#    {'id': 'MET_I3',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I3',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Definition of permanent incapacity',
#     'nameES': 'DefiniciÃ³n de incapacidad permanente',
#     'nameFR': "DÃ©finition d'incapacitÃ© permanente"},
#    {'id': 'MET_I6',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I6',
#     'coreRepresentation': 'CL_NOTE_I6',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Type of severity rate for strikes and lockouts',
#     'nameES': 'Tipo de tasa de severidad de huelgas y cierres patronales',
#     'nameFR': 'Type de taux de gravitÃ© des grÃ¨ves et lock-outs'},
#    {'id': 'OVN_C9',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C9',
#     'coreRepresentation': 'CL_NOTE_C9',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Adjustments',
#     'nameES': 'Ajustes',
#     'nameFR': 'Ajustements'},
#    {'id': 'OVN_C10',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C10',
#     'coreRepresentation': 'CL_NOTE_C10',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Type of primary source',
#     'nameES': 'Tipo de fuente primaria',
#     'nameFR': 'Type de source primaire'},
#    {'id': 'OVN_C12',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C12',
#     'coreRepresentation': 'CL_NOTE_C12',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Rural / urban areas coverage definition',
#     'nameES': 'zonas rurales / urbanas cobertura definiciÃ³n',
#     'nameFR': 'Couverture des zones rurales / urbaines dÃ©finition'},
#    {'id': 'MET_R1',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_R1',
#     'coreRepresentation': 'CL_NOTE_R1',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Repository',
#     'nameES': 'Repositorio',
#     'nameFR': 'Repositoire'},
#    {'id': 'OVN_C8',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C8',
#     'coreRepresentation': 'CL_NOTE_C8',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nonstandard hours band',
#     'nameES': 'Banda de horas no estÃ¡ndar',
#     'nameFR': 'Bande des heures non standard'},
#    {'id': 'OVN_C11',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C11',
#     'coreRepresentation': 'CL_NOTE_C11',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Data quality',
#     'nameES': 'Calidad de los datos',
#     'nameFR': 'QualitÃ© des donnÃ©es'},
#    {'id': 'MET_S13',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S13',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Name & email of contact person',
#     'nameES': 'Nombre y correo electrÃ³nico de la persona de contacto',
#     'nameFR': 'Nom et courriel de la personne de contact'},
#    {'id': 'MET_T35',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T35',
#     'coreRepresentation': 'CL_NOTE_T35',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Time-related underemployment concept',
#     'nameES': 'Concepto del subempleo por insuficiencia de horas',
#     'nameFR': 'Concept du sous-emploi liÃ© Ã\xa0 la durÃ©e du travail'},
#    {'id': 'MET_T36',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T36',
#     'coreRepresentation': 'CL_NOTE_T36',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Definition of migrants',
#     'nameES': 'DefiniciÃ³n de los migrantes',
#     'nameFR': 'DÃ©finition des migrants'},
#    {'id': 'MET_I8',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I8',
#     'coreRepresentation': 'CL_NOTE_I8',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Criteria used to define rural/urban areas',
#     'nameES': 'Criterios para definir las zonas rurales/urbanas',
#     'nameFR': 'CritÃ¨res pour dÃ©finir les zones rurales/ubaines'},
#    {'id': 'MET_T37',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T37',
#     'coreRepresentation': 'CL_NOTE_T37',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Socio-economic vulnerability',
#     'nameES': 'Vulnerabilidad socio- econÃ³mica',
#     'nameFR': 'VulnÃ©rabilitÃ© socio -Ã©conomique'},
#    {'id': 'MET_T38',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T38',
#     'coreRepresentation': 'CL_NOTE_T38',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Informal employment definition',
#     'nameES': 'DefiniciÃ³n del empleo informal',
#     'nameFR': "DÃ©finition de l'emploi informel"},
#    {'id': 'MET_I10',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I10',
#     'coreRepresentation': 'CL_NOTE_I10',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Part-time threshold',
#     'nameES': 'LÃ\xadmite utilizado para el tiempo parcial',
#     'nameFR': 'Seuil utilisÃ© pour le temps partiel'},
#    {'id': 'MET_I16',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I16',
#     'coreRepresentation': 'CL_NOTE_I16',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Source of funding of parental leave cash benefits',
#     'nameES': 'Fuente de financiaciÃ³n de las prestaciones monetarias de permiso parental',
#     'nameFR': 'Source de financement des prestations en espÃ¨ces de congÃ© parental'},
#    {'id': 'MET_I18',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I18',
#     'coreRepresentation': 'CL_NOTE_I18',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nursing/childcare facilities at workplace (or childcare reimbursement)',
#     'nameES': 'Instalaciones para la lactancia o guarderÃ\xada en el lugar de trabajo (o reembolso por el cuidado de niÃ±os)',
#     'nameFR': "Installations pour l'allaitement maternel ou garde d'enfants au lieu de travail (ou le remboursement de garde d'enfants)"},
#    {'id': 'MET_I14',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I14',
#     'coreRepresentation': 'CL_NOTE_I14',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Source of funding of maternity leave cash benefits',
#     'nameES': 'Fuente de financiaciÃ³n de las prestaciones monetarias de permiso de maternidad',
#     'nameFR': 'Source de financement des prestations en espÃ¨ces de congÃ© de maternitÃ©'},
#    {'id': 'MET_I15',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I15',
#     'coreRepresentation': 'CL_NOTE_I15',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Source of funding of paternity leave cash benefits',
#     'nameES': 'Fuente de financiaciÃ³n de las prestaciones monetarias de permiso de paternidad',
#     'nameFR': 'Source de financement des prestations en espÃ¨ces de congÃ© de paternitÃ©'},
#    {'id': 'MET_I17',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I17',
#     'coreRepresentation': 'CL_NOTE_I17',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Entitlement to paid nursing breaks',
#     'nameES': 'Derecho a las interrupciones para la lactancia pagados',
#     'nameFR': "Droit aux pauses d'allaitement rÃ©munÃ©rÃ©es"},
#    {'id': 'MET_I19',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I19',
#     'coreRepresentation': 'CL_NOTE_I19',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Type of minimum wage',
#     'nameES': 'Tipo de salario mÃ\xadnimo',
#     'nameFR': 'Type de salaire minimum'},
#    {'id': 'MET_I22',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I22',
#     'coreRepresentation': 'CL_NOTE_I22',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Economic units in the informal sector',
#     'nameES': 'Unidades econÃ³micas en el sector informal',
#     'nameFR': 'UnitÃ©s Ã©conomiques dans le secteur informel'},
#    {'id': 'MET_I20',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I20',
#     'coreRepresentation': 'CL_NOTE_I20',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Informal employees',
#     'nameES': 'Asalariados informales',
#     'nameFR': 'SalariÃ©s informels'},
#    {'id': 'MET_I21',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I21',
#     'coreRepresentation': 'CL_NOTE_I21',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Workers in informal employment',
#     'nameES': 'Trabajadores en el empleo informal',
#     'nameFR': "Travailleurs dans l'emploi informel"},
#    {'id': 'OVN_C13',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C13',
#     'coreRepresentation': 'CL_NOTE_C13',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Nonstandard sector',
#     'nameES': 'Sector no estÃ¡ndar',
#     'nameFR': 'Secteur non standard'},
#    {'id': 'MET_I26',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I26',
#     'coreRepresentation': 'CL_NOTE_I26',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Minimum duration of disability',
#     'nameES': 'DuraciÃ³n mÃ\xadnima de la discapacidad',
#     'nameFR': "DurÃ©e minimale de l'handicap"},
#    {'id': 'MET_I24',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I24',
#     'coreRepresentation': 'CL_NOTE_I24',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Type of difficulties',
#     'nameES': 'Tipo de dificultades',
#     'nameFR': 'Type de difficultÃ©s'},
#    {'id': 'MET_I25',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I25',
#     'coreRepresentation': 'CL_NOTE_I25',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Level of difficulties',
#     'nameES': 'Nivel de dificultades',
#     'nameFR': 'Niveau de difficultÃ©s'},
#    {'id': 'MET_T39',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_T39',
#     'coreRepresentation': 'CL_NOTE_T39',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Criteria used to define persons with disability',
#     'nameES': 'Criterios utilizados para definir las personas con discapacidad',
#     'nameFR': 'CritÃ¨res utilisÃ©s pour dÃ©finir les personnes handicapÃ©es'},
#    {'id': 'MET_I27',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I27',
#     'coreRepresentation': 'CL_NOTE_I27',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Coverage of temporary employees',
#     'nameES': 'Cobertura de asalariados temporarios',
#     'nameFR': 'Couverture des salariÃ©s temporaires'},
#    {'id': 'MET_I23',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I23',
#     'coreRepresentation': 'CL_NOTE_I23',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Public sector coverage',
#     'nameES': 'Cobertura del sector pÃºblico',
#     'nameFR': 'Couverture du secteur public'},
#    {'id': 'MET_S14',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_S14',
#     'coreRepresentation': 'CL_NOTE_S14',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Employment definition',
#     'nameES': 'DefiniciÃ³n de empleo',
#     'nameFR': "DÃ©finition de l'emploi"},
#    {'id': 'OVN_C94',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C94',
#     'coreRepresentation': 'CL_NOTE_C94',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'ThirdCountryTotalization',
#     'nameES': '...',
#     'nameFR': '...'},
#    {'id': 'OVN_C95',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C95',
#     'coreRepresentation': 'CL_NOTE_C95',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'PostedWorkers-InitialPeriod',
#     'nameES': '...',
#     'nameFR': '...'},
#    {'id': 'OVN_C96',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C96',
#     'coreRepresentation': 'CL_NOTE_C96',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'PostedWorkers-MaxPeriod',
#     'nameES': '...',
#     'nameFR': '...'},
#    {'id': 'OVN_C97',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C97',
#     'coreRepresentation': 'CL_NOTE_C97',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'SelfEmployed-InitialPeriod',
#     'nameES': '...',
#     'nameFR': '...'},
#    {'id': 'OVN_C98',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C98',
#     'coreRepresentation': 'CL_NOTE_C98',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'SelfEmployed-MaxPeriod',
#     'nameES': '...',
#     'nameFR': '...'},
#    {'id': 'MET_I33',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).MET_I33',
#     'coreRepresentation': 'CL_NOTE_I33',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'ILO calculation',
#     'nameES': 'CÃ¡lculo de la OIT',
#     'nameFR': 'Calcul du BIT'},
#    {'id': 'OVN_C90',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C90',
#     'coreRepresentation': 'CL_NOTE_C90',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Months for temporary',
#     'nameES': None,
#     'nameFR': None},
#    {'id': 'OVN_C92',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C92',
#     'coreRepresentation': 'CL_NOTE_C92',
#     'coreRepresentationAgency': 'ILO',
#     'nameEN': 'Date of entry into force',
#     'nameES': '...',
#     'nameFR': '...'},
#    {'id': 'OVN_C91',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C91',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Agreement ID',
#     'nameES': None,
#     'nameFR': None},
#    {'id': 'OVN_C93',
#     'urn': 'urn:sdmx:org.sdmx.infomodel.conceptscheme.Concept=ILO:CS_NOTE_TYPE(1.0).OVN_C93',
#     'coreRepresentation': None,
#     'coreRepresentationAgency': None,
#     'nameEN': 'Document link',
#     'nameES': None,
#     'nameFR': None}]}]

# %%
    for x in codeSchemeName:
        if x['@xml:lang'] == 'en':
            codeScheme['nameEN'] = x['#text']
        if x['@xml:lang'] == 'es':
            codeScheme['nameES'] = x['#text']
        if x['@xml:lang'] == 'fr':
            codeScheme['nameFR'] = x['#text']

    codeScheme['concepts'] = []
    
codeList

codeList['codes'] = []
for c in level3['str:Code']:
    code = {}
    code['value'] = c['@value']
    
    codeValueDescription = c['str:Description']
    for x in codeValueDescription:
        if x['@xml:lang'] == 'en':
            code['descriptionEN'] = x['#text']
        if x['@xml:lang'] == 'es':
            code['descriptionES'] = x['#text']
        if x['@xml:lang'] == 'fr':
            code['descriptionFR'] = x['#text']
    codeList['codes'].append(code)
